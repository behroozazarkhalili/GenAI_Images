# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/ermia/anaconda3/envs/deep-shap/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/ermia/anaconda3/envs/deep-shap/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim, categorical_dim, continuous_dim):
        super(Generator, self).__init__()
        self.latent_dim = latent_dim
        self.categorical_dim = categorical_dim
        self.continuous_dim = continuous_dim

        self.fc1 = nn.Linear(latent_dim + categorical_dim + continuous_dim, 1024)
        self.fc2 = nn.Linear(1024, 128 * 7 * 7)
        self.bn2 = nn.BatchNorm1d(128 * 7 * 7)
        self.conv1 = nn.ConvTranspose2d(128, 64, 4, 2, 1)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv2 = nn.ConvTranspose2d(64, 1, 4, 2, 1)

    def forward(self, z, c1, c2):
        inputs = torch.cat([z, c1, c2], 1)
        x = F.leaky_relu(self.fc1(inputs), 0.2)
        x = F.leaky_relu(self.bn2(self.fc2(x)), 0.2)
        x = x.view(-1, 128, 7, 7)
        x = F.leaky_relu(self.bn3(self.conv1(x)), 0.2)
        x = torch.tanh(self.conv2(x))
        return x

class Discriminator(nn.Module):
    def __init__(self, categorical_dim, continuous_dim):
        super(Discriminator, self).__init__()
        self.categorical_dim = categorical_dim
        self.continuous_dim = continuous_dim

        self.conv1 = nn.Conv2d(1, 64, 4, 2, 1)
        self.conv2 = nn.Conv2d(64, 128, 4, 2, 1)
        self.bn2 = nn.BatchNorm2d(128)
        self.fc1 = nn.Linear(128 * 7 * 7, 1024)
        self.bn3 = nn.BatchNorm1d(1024)
        self.fc2 = nn.Linear(1024, 1)
        self.fc3 = nn.Linear(1024, categorical_dim)
        self.fc4 = nn.Linear(1024, continuous_dim)

    def forward(self, x):
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.bn2(self.conv2(x)), 0.2)
        x = x.view(-1, 128 * 7 * 7)
        x = F.leaky_relu(self.bn3(self.fc1(x)), 0.2)
        d = torch.sigmoid(self.fc2(x))
        c1 = self.fc3(x)
        c2 = self.fc4(x)
        return d, c1, c2

class InfoGAN:
    def __init__(self, latent_dim, categorical_dim, continuous_dim, lr=0.0002, beta1=0.5):
        self.latent_dim = latent_dim
        self.categorical_dim = categorical_dim
        self.continuous_dim = continuous_dim

        self.generator = Generator(latent_dim, categorical_dim, continuous_dim)
        self.discriminator = Discriminator(categorical_dim, continuous_dim)

        self.g_optimizer = optim.Adam(self.generator.parameters(), lr=lr, betas=(beta1, 0.999))
        self.d_optimizer = optim.Adam(self.discriminator.parameters(), lr=lr, betas=(beta1, 0.999))

        self.criterion = nn.BCELoss()
        self.categorical_loss = nn.CrossEntropyLoss()
        self.continuous_loss = nn.MSELoss()

    def train_step(self, real_data):
        batch_size = real_data.size(0)
        real_labels = torch.ones(batch_size, 1)
        fake_labels = torch.zeros(batch_size, 1)

        # Train Discriminator and Q-network
        self.d_optimizer.zero_grad()

        d_real_output, _, _ = self.discriminator(real_data)
        d_real_loss = self.criterion(d_real_output, real_labels)

        z = torch.randn(batch_size, self.latent_dim)
        c1 = torch.zeros(batch_size, self.categorical_dim).scatter_(1, torch.randint(0, self.categorical_dim, (batch_size, 1)), 1)
        c2 = torch.rand(batch_size, self.continuous_dim)
        fake_data = self.generator(z, c1, c2)
        d_fake_output, q_c1, q_c2 = self.discriminator(fake_data.detach())
        d_fake_loss = self.criterion(d_fake_output, fake_labels)

        q_loss = self.categorical_loss(q_c1, torch.max(c1, 1)[1]) + self.continuous_loss(q_c2, c2)
        d_loss = d_real_loss + d_fake_loss + q_loss
        d_loss.backward()
        self.d_optimizer.step()

        # Train Generator
        self.g_optimizer.zero_grad()

        z = torch.randn(batch_size, self.latent_dim)
        c1 = torch.zeros(batch_size, self.categorical_dim).scatter_(1, torch.randint(0, self.categorical_dim, (batch_size, 1)), 1)
        c2 = torch.rand(batch_size, self.continuous_dim)
        fake_data = self.generator(z, c1, c2)
        g_fake_output, q_c1, q_c2 = self.discriminator(fake_data)
        g_loss = self.criterion(g_fake_output, real_labels)
        q_loss = self.categorical_loss(q_c1, torch.max(c1, 1)[1]) + self.continuous_loss(q_c2, c2)
        g_total_loss = g_loss + q_loss
        g_total_loss.backward()
        self.g_optimizer.step()

        return d_loss.item(), g_total_loss.item(), q_loss.item()

def train_infogan(infogan, dataloader, num_epochs, device):
    infogan.generator.to(device)
    infogan.discriminator.to(device)

    for epoch in range(num_epochs):
        for i, (real_data, _) in enumerate(dataloader):
            real_data = real_data.to(device)
            d_loss, g_loss, q_loss = infogan.train_step(real_data)

            if i % 100 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(dataloader)}], '
                      f'd_loss: {d_loss:.4f}, g_loss: {g_loss:.4f}, q_loss: {q_loss:.4f}')

def visualize_results(infogan, latent_dim, categorical_dim, continuous_dim, num_samples=10):
    infogan.generator.eval()
    with torch.no_grad():
        for category in range(categorical_dim):
            z = torch.randn(num_samples, latent_dim)
            c1 = torch.zeros(num_samples, categorical_dim)
            c1[:, category] = 1
            c2 = torch.linspace(0, 1, num_samples).unsqueeze(1).repeat(1, continuous_dim)
            
            fake_data = infogan.generator(z, c1, c2)
            fake_data = fake_data.view(num_samples, 28, 28).cpu().numpy()
            
            fig, axes = plt.subplots(1, num_samples, figsize=(num_samples*2, 2))
            for j, ax in enumerate(axes):
                ax.imshow(fake_data[j], cmap='gray')
                ax.axis('off')
            plt.title(f'Category {category}')
            plt.savefig(f'infogan_category_{category}.jpg', dpi=300, bbox_inches='tight', pad_inches=0)
            plt.show()

# %%
# Example usage
if __name__ == "__main__":
    latent_dim = 62
    categorical_dim = 10
    continuous_dim = 2
    batch_size = 64
    num_epochs = 50

    # Load MNIST dataset
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])
    mnist = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    dataloader = DataLoader(mnist, batch_size=batch_size, shuffle=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    infogan = InfoGAN(latent_dim, categorical_dim, continuous_dim)
    train_infogan(infogan, dataloader, num_epochs, device)
    visualize_results(infogan, latent_dim, categorical_dim, continuous_dim)
# Out:
# /home/ermia/anaconda3/envs/deep-shap/lib/python3.10/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Epoch [1/1], Step [1/938], d_loss: 4.1882, g_loss: 3.5632, q_loss: 2.8870
# Epoch [1/1], Step [101/938], d_loss: 1.2396, g_loss: 0.9965, q_loss: 0.1189
# Epoch [1/1], Step [201/938], d_loss: 0.9556, g_loss: 1.2812, q_loss: 0.0953
# Epoch [1/1], Step [301/938], d_loss: 0.9453, g_loss: 1.4791, q_loss: 0.1134
# Epoch [1/1], Step [401/938], d_loss: 0.7748, g_loss: 1.6982, q_loss: 0.1275
# Epoch [1/1], Step [501/938], d_loss: 0.6573, g_loss: 1.8443, q_loss: 0.1173
# Epoch [1/1], Step [601/938], d_loss: 0.9231, g_loss: 1.8690, q_loss: 0.1069
# Epoch [1/1], Step [701/938], d_loss: 0.7319, g_loss: 1.8735, q_loss: 0.1280
# Epoch [1/1], Step [801/938], d_loss: 0.7066, g_loss: 1.9231, q_loss: 0.1161
# Epoch [1/1], Step [901/938], d_loss: 0.6609, g_loss: 1.7952, q_loss: 0.1034

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt

class Generator(nn.Module):
    def __init__(self, latent_dim, categorical_dim, continuous_dim, num_classes):
        super(Generator, self).__init__()
        self.latent_dim = latent_dim
        self.categorical_dim = categorical_dim
        self.continuous_dim = continuous_dim
        self.num_classes = num_classes

        total_dim = latent_dim + categorical_dim + continuous_dim + num_classes

        self.fc1 = nn.Linear(total_dim, 1024)
        self.fc2 = nn.Linear(1024, 128 * 7 * 7)
        self.bn2 = nn.BatchNorm1d(128 * 7 * 7)
        self.conv1 = nn.ConvTranspose2d(128, 64, 4, 2, 1)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv2 = nn.ConvTranspose2d(64, 1, 4, 2, 1)

    def forward(self, z, c1, c2, labels):
        inputs = torch.cat([z, c1, c2, labels], 1)
        x = F.leaky_relu(self.fc1(inputs), 0.2)
        x = F.leaky_relu(self.bn2(self.fc2(x)), 0.2)
        x = x.view(-1, 128, 7, 7)
        x = F.leaky_relu(self.bn3(self.conv1(x)), 0.2)
        x = torch.tanh(self.conv2(x))
        return x

class Discriminator(nn.Module):
    def __init__(self, categorical_dim, continuous_dim, num_classes):
        super(Discriminator, self).__init__()
        self.categorical_dim = categorical_dim
        self.continuous_dim = continuous_dim
        self.num_classes = num_classes

        self.conv1 = nn.Conv2d(1, 64, 4, 2, 1)
        self.conv2 = nn.Conv2d(64, 128, 4, 2, 1)
        self.bn2 = nn.BatchNorm2d(128)
        self.fc1 = nn.Linear(128 * 7 * 7, 1024)
        self.bn3 = nn.BatchNorm1d(1024)
        self.fc2 = nn.Linear(1024, 1)
        self.fc3 = nn.Linear(1024, categorical_dim)
        self.fc4 = nn.Linear(1024, continuous_dim)
        self.fc5 = nn.Linear(1024, num_classes)

    def forward(self, x):
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.bn2(self.conv2(x)), 0.2)
        x = x.view(-1, 128 * 7 * 7)
        x = F.leaky_relu(self.bn3(self.fc1(x)), 0.2)
        d = torch.sigmoid(self.fc2(x))
        c1 = self.fc3(x)
        c2 = self.fc4(x)
        c_class = self.fc5(x)
        return d, c1, c2, c_class

class ConditionalInfoGAN:
    def __init__(self, latent_dim, categorical_dim, continuous_dim, num_classes, lr=0.0002, beta1=0.5):
        self.latent_dim = latent_dim
        self.categorical_dim = categorical_dim
        self.continuous_dim = continuous_dim
        self.num_classes = num_classes

        self.generator = Generator(latent_dim, categorical_dim, continuous_dim, num_classes)
        self.discriminator = Discriminator(categorical_dim, continuous_dim, num_classes)

        self.g_optimizer = optim.Adam(self.generator.parameters(), lr=lr, betas=(beta1, 0.999))
        self.d_optimizer = optim.Adam(self.discriminator.parameters(), lr=lr, betas=(beta1, 0.999))

        self.criterion = nn.BCELoss()
        self.categorical_loss = nn.CrossEntropyLoss()
        self.continuous_loss = nn.MSELoss()
        self.class_loss = nn.CrossEntropyLoss()

    def train_step(self, real_data, labels):
        batch_size = real_data.size(0)
        real_labels = torch.ones(batch_size, 1)
        fake_labels = torch.zeros(batch_size, 1)

        # One-hot encode the labels
        labels_onehot = F.one_hot(labels, num_classes=self.num_classes).float()

        # Train Discriminator and Q-network
        self.d_optimizer.zero_grad()

        d_real_output, _, _, c_real_class = self.discriminator(real_data)
        d_real_loss = self.criterion(d_real_output, real_labels)
        c_real_loss = self.class_loss(c_real_class, labels)

        z = torch.randn(batch_size, self.latent_dim)
        c1 = torch.zeros(batch_size, self.categorical_dim).scatter_(1, torch.randint(0, self.categorical_dim, (batch_size, 1)), 1)
        c2 = torch.rand(batch_size, self.continuous_dim)
        fake_data = self.generator(z, c1, c2, labels_onehot)
        d_fake_output, q_c1, q_c2, c_fake_class = self.discriminator(fake_data.detach())
        d_fake_loss = self.criterion(d_fake_output, fake_labels)

        q_loss = self.categorical_loss(q_c1, torch.max(c1, 1)[1]) + self.continuous_loss(q_c2, c2)
        c_fake_loss = self.class_loss(c_fake_class, labels)
        d_loss = d_real_loss + d_fake_loss + q_loss + c_real_loss + c_fake_loss
        d_loss.backward()
        self.d_optimizer.step()

        # Train Generator
        self.g_optimizer.zero_grad()

        z = torch.randn(batch_size, self.latent_dim)
        c1 = torch.zeros(batch_size, self.categorical_dim).scatter_(1, torch.randint(0, self.categorical_dim, (batch_size, 1)), 1)
        c2 = torch.rand(batch_size, self.continuous_dim)
        fake_data = self.generator(z, c1, c2, labels_onehot)
        g_fake_output, q_c1, q_c2, c_fake_class = self.discriminator(fake_data)
        g_loss = self.criterion(g_fake_output, real_labels)
        q_loss = self.categorical_loss(q_c1, torch.max(c1, 1)[1]) + self.continuous_loss(q_c2, c2)
        c_fake_loss = self.class_loss(c_fake_class, labels)
        g_total_loss = g_loss + q_loss + c_fake_loss
        g_total_loss.backward()
        self.g_optimizer.step()

        return d_loss.item(), g_total_loss.item(), q_loss.item(), c_real_loss.item(), c_fake_loss.item()

def train_conditional_infogan(cinfogan, dataloader, num_epochs, device):
    cinfogan.generator.to(device)
    cinfogan.discriminator.to(device)

    for epoch in range(num_epochs):
        for i, (real_data, labels) in enumerate(dataloader):
            real_data = real_data.to(device)
            labels = labels.to(device)
            d_loss, g_loss, q_loss, c_real_loss, c_fake_loss = cinfogan.train_step(real_data, labels)

            if i % 100 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(dataloader)}], '
                      f'd_loss: {d_loss:.4f}, g_loss: {g_loss:.4f}, q_loss: {q_loss:.4f}, '
                      f'c_real_loss: {c_real_loss:.4f}, c_fake_loss: {c_fake_loss:.4f}')

def visualize_conditional_results(cinfogan, latent_dim, categorical_dim, continuous_dim, num_classes, num_samples=10):
    cinfogan.generator.eval()
    with torch.no_grad():
        for category in range(categorical_dim):
            z = torch.randn(num_samples, latent_dim)
            c1 = torch.zeros(num_samples, categorical_dim)
            c1[:, category] = 1
            c2 = torch.linspace(0, 1, num_samples).unsqueeze(1).repeat(1, continuous_dim)
            
            fig, axes = plt.subplots(num_classes, num_samples, figsize=(num_samples*2, num_classes*2))
            for class_label in range(num_classes):
                labels_onehot = F.one_hot(torch.full((num_samples,), class_label, dtype=torch.long), num_classes=num_classes).float()
                fake_data = cinfogan.generator(z, c1, c2, labels_onehot)
                fake_data = fake_data.view(num_samples, 28, 28).cpu().numpy()
                
                for j, ax in enumerate(axes[class_label]):
                    ax.imshow(fake_data[j], cmap='gray')
                    ax.axis('off')
                    if j == 0:
                        ax.set_title(f'Class {class_label}')
            plt.suptitle(f'Category {category}')
            plt.tight_layout()
            plt.savefig(f'conditional_infogan_category_{category}.jpg', dpi=300, bbox_inches='tight', pad_inches=0)
            plt.show()
# Out:
# /home/ermia/anaconda3/envs/deep-shap/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/home/ermia/anaconda3/envs/deep-shap/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
# Example usage
if __name__ == "__main__":
    latent_dim = 62
    categorical_dim = 10
    continuous_dim = 2
    num_classes = 10  # For MNIST
    batch_size = 64
    num_epochs = 100

    # Load MNIST dataset
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])
    mnist = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
    dataloader = DataLoader(mnist, batch_size=batch_size, shuffle=True)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    cinfogan = ConditionalInfoGAN(latent_dim, categorical_dim, continuous_dim, num_classes)
    train_conditional_infogan(cinfogan, dataloader, num_epochs, device)
    visualize_conditional_results(cinfogan, latent_dim, categorical_dim, continuous_dim, num_classes)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 12214771.60it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 469767.64it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 3575584.21it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2533315.00it/s]
# /home/ermia/anaconda3/envs/deep-shap/lib/python3.10/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Epoch [1/100], Step [1/938], d_loss: 9.1420, g_loss: 5.9621, q_loss: 2.9412, c_real_loss: 2.4057, c_fake_loss: 2.2865
# Epoch [1/100], Step [101/938], d_loss: 1.4709, g_loss: 0.9555, q_loss: 0.1201, c_real_loss: 0.0972, c_fake_loss: 0.0350
# Epoch [1/100], Step [201/938], d_loss: 1.2171, g_loss: 1.1623, q_loss: 0.0818, c_real_loss: 0.2019, c_fake_loss: 0.0139
# Epoch [1/100], Step [301/938], d_loss: 0.8395, g_loss: 1.4464, q_loss: 0.0635, c_real_loss: 0.0307, c_fake_loss: 0.0353
# Epoch [1/100], Step [401/938], d_loss: 0.8921, g_loss: 1.7412, q_loss: 0.0698, c_real_loss: 0.1463, c_fake_loss: 0.0373
# Epoch [1/100], Step [501/938], d_loss: 0.8410, g_loss: 1.9404, q_loss: 0.0996, c_real_loss: 0.2051, c_fake_loss: 0.0277
# Epoch [1/100], Step [601/938], d_loss: 0.8717, g_loss: 1.8576, q_loss: 0.1768, c_real_loss: 0.1159, c_fake_loss: 0.0485
# Epoch [1/100], Step [701/938], d_loss: 1.0815, g_loss: 1.7931, q_loss: 0.1083, c_real_loss: 0.1150, c_fake_loss: 0.0461
# Epoch [1/100], Step [801/938], d_loss: 0.9322, g_loss: 1.6192, q_loss: 0.0884, c_real_loss: 0.1873, c_fake_loss: 0.1125
# Epoch [1/100], Step [901/938], d_loss: 1.2132, g_loss: 1.6425, q_loss: 0.1389, c_real_loss: 0.0696, c_fake_loss: 0.0340
# Epoch [2/100], Step [1/938], d_loss: 1.1058, g_loss: 1.5921, q_loss: 0.0783, c_real_loss: 0.0690, c_fake_loss: 0.0339
# Epoch [2/100], Step [101/938], d_loss: 0.8239, g_loss: 1.7430, q_loss: 0.0854, c_real_loss: 0.0706, c_fake_loss: 0.0115
# Epoch [2/100], Step [201/938], d_loss: 1.0120, g_loss: 1.6148, q_loss: 0.0904, c_real_loss: 0.0961, c_fake_loss: 0.0125
# Epoch [2/100], Step [301/938], d_loss: 0.8996, g_loss: 1.8504, q_loss: 0.1440, c_real_loss: 0.0605, c_fake_loss: 0.0217
# Epoch [2/100], Step [401/938], d_loss: 0.7892, g_loss: 1.9706, q_loss: 0.0822, c_real_loss: 0.0940, c_fake_loss: 0.0063
# Epoch [2/100], Step [501/938], d_loss: 0.8043, g_loss: 1.8420, q_loss: 0.1807, c_real_loss: 0.0323, c_fake_loss: 0.0608
# Epoch [2/100], Step [601/938], d_loss: 0.9464, g_loss: 1.6376, q_loss: 0.1024, c_real_loss: 0.0325, c_fake_loss: 0.0157
# Epoch [2/100], Step [701/938], d_loss: 0.9492, g_loss: 1.5939, q_loss: 0.0952, c_real_loss: 0.0646, c_fake_loss: 0.0189
# Epoch [2/100], Step [801/938], d_loss: 1.0756, g_loss: 1.7881, q_loss: 0.0920, c_real_loss: 0.1662, c_fake_loss: 0.0452
# Epoch [2/100], Step [901/938], d_loss: 0.8248, g_loss: 1.7615, q_loss: 0.1068, c_real_loss: 0.0196, c_fake_loss: 0.0192
# Epoch [3/100], Step [1/938], d_loss: 0.9948, g_loss: 2.2203, q_loss: 0.1607, c_real_loss: 0.0351, c_fake_loss: 0.1120
# Epoch [3/100], Step [101/938], d_loss: 0.9539, g_loss: 1.8047, q_loss: 0.1291, c_real_loss: 0.0175, c_fake_loss: 0.0193
# Epoch [3/100], Step [201/938], d_loss: 0.8220, g_loss: 2.1412, q_loss: 0.2224, c_real_loss: 0.0203, c_fake_loss: 0.0302
# Epoch [3/100], Step [301/938], d_loss: 0.8374, g_loss: 1.7110, q_loss: 0.1461, c_real_loss: 0.0318, c_fake_loss: 0.0137
# Epoch [3/100], Step [401/938], d_loss: 0.9569, g_loss: 1.5969, q_loss: 0.1647, c_real_loss: 0.0811, c_fake_loss: 0.0106
# Epoch [3/100], Step [501/938], d_loss: 1.1140, g_loss: 1.8617, q_loss: 0.1255, c_real_loss: 0.1032, c_fake_loss: 0.0384
# Epoch [3/100], Step [601/938], d_loss: 0.9795, g_loss: 1.8015, q_loss: 0.1383, c_real_loss: 0.0200, c_fake_loss: 0.0148
# Epoch [3/100], Step [701/938], d_loss: 0.8214, g_loss: 1.9521, q_loss: 0.0908, c_real_loss: 0.0074, c_fake_loss: 0.0124
# Epoch [3/100], Step [801/938], d_loss: 1.0580, g_loss: 1.8501, q_loss: 0.1249, c_real_loss: 0.1171, c_fake_loss: 0.0533
# Epoch [3/100], Step [901/938], d_loss: 1.0241, g_loss: 2.0087, q_loss: 0.1654, c_real_loss: 0.0295, c_fake_loss: 0.0134
# Epoch [4/100], Step [1/938], d_loss: 0.9508, g_loss: 1.6919, q_loss: 0.3038, c_real_loss: 0.0234, c_fake_loss: 0.0047
# Epoch [4/100], Step [101/938], d_loss: 0.9594, g_loss: 1.8529, q_loss: 0.1175, c_real_loss: 0.1073, c_fake_loss: 0.0186
# Epoch [4/100], Step [201/938], d_loss: 1.0258, g_loss: 1.9671, q_loss: 0.1154, c_real_loss: 0.0490, c_fake_loss: 0.0625
# Epoch [4/100], Step [301/938], d_loss: 0.9897, g_loss: 1.6925, q_loss: 0.1649, c_real_loss: 0.0614, c_fake_loss: 0.0069
# Epoch [4/100], Step [401/938], d_loss: 0.8892, g_loss: 1.5795, q_loss: 0.1506, c_real_loss: 0.0644, c_fake_loss: 0.0025
# Epoch [4/100], Step [501/938], d_loss: 0.9473, g_loss: 1.7509, q_loss: 0.0836, c_real_loss: 0.0456, c_fake_loss: 0.0127
# Epoch [4/100], Step [601/938], d_loss: 1.0760, g_loss: 1.7360, q_loss: 0.2025, c_real_loss: 0.0211, c_fake_loss: 0.0046
# Epoch [4/100], Step [701/938], d_loss: 1.1028, g_loss: 1.6887, q_loss: 0.0934, c_real_loss: 0.0469, c_fake_loss: 0.0072
# Epoch [4/100], Step [801/938], d_loss: 0.9519, g_loss: 1.7843, q_loss: 0.1429, c_real_loss: 0.0033, c_fake_loss: 0.0065
# Epoch [4/100], Step [901/938], d_loss: 0.9633, g_loss: 1.6302, q_loss: 0.0884, c_real_loss: 0.0474, c_fake_loss: 0.0038
# Epoch [5/100], Step [1/938], d_loss: 0.9979, g_loss: 1.6504, q_loss: 0.0850, c_real_loss: 0.0174, c_fake_loss: 0.0412
# Epoch [5/100], Step [101/938], d_loss: 0.9301, g_loss: 1.5306, q_loss: 0.1381, c_real_loss: 0.0267, c_fake_loss: 0.0023
# Epoch [5/100], Step [201/938], d_loss: 0.9686, g_loss: 1.6910, q_loss: 0.0667, c_real_loss: 0.0108, c_fake_loss: 0.0054
# Epoch [5/100], Step [301/938], d_loss: 0.8505, g_loss: 1.5991, q_loss: 0.0849, c_real_loss: 0.0300, c_fake_loss: 0.0015
# Epoch [5/100], Step [401/938], d_loss: 0.9564, g_loss: 1.7948, q_loss: 0.2510, c_real_loss: 0.0101, c_fake_loss: 0.0208
# Epoch [5/100], Step [501/938], d_loss: 0.9450, g_loss: 1.7243, q_loss: 0.1803, c_real_loss: 0.0138, c_fake_loss: 0.0077
# Epoch [5/100], Step [601/938], d_loss: 0.7699, g_loss: 1.8202, q_loss: 0.1354, c_real_loss: 0.0221, c_fake_loss: 0.0096
# Epoch [5/100], Step [701/938], d_loss: 1.2014, g_loss: 1.6577, q_loss: 0.1440, c_real_loss: 0.0753, c_fake_loss: 0.0120
# Epoch [5/100], Step [801/938], d_loss: 0.8918, g_loss: 1.7064, q_loss: 0.2417, c_real_loss: 0.0101, c_fake_loss: 0.0181
# Epoch [5/100], Step [901/938], d_loss: 0.9006, g_loss: 1.8238, q_loss: 0.0678, c_real_loss: 0.0221, c_fake_loss: 0.0048
# Epoch [6/100], Step [1/938], d_loss: 0.8561, g_loss: 1.7442, q_loss: 0.0779, c_real_loss: 0.0144, c_fake_loss: 0.0035
# Epoch [6/100], Step [101/938], d_loss: 0.8420, g_loss: 2.1433, q_loss: 0.1725, c_real_loss: 0.0216, c_fake_loss: 0.0075
# Epoch [6/100], Step [201/938], d_loss: 1.1019, g_loss: 1.6428, q_loss: 0.2035, c_real_loss: 0.0158, c_fake_loss: 0.0133
# Epoch [6/100], Step [301/938], d_loss: 1.0248, g_loss: 1.5896, q_loss: 0.0644, c_real_loss: 0.0349, c_fake_loss: 0.0032
# Epoch [6/100], Step [401/938], d_loss: 0.9890, g_loss: 1.6991, q_loss: 0.0750, c_real_loss: 0.0138, c_fake_loss: 0.0085
# Epoch [6/100], Step [501/938], d_loss: 0.9949, g_loss: 1.8571, q_loss: 0.2484, c_real_loss: 0.0166, c_fake_loss: 0.0106
# Epoch [6/100], Step [601/938], d_loss: 0.8015, g_loss: 1.6604, q_loss: 0.0418, c_real_loss: 0.0515, c_fake_loss: 0.0026
# Epoch [6/100], Step [701/938], d_loss: 0.8762, g_loss: 1.9734, q_loss: 0.0571, c_real_loss: 0.0273, c_fake_loss: 0.1439
# Epoch [6/100], Step [801/938], d_loss: 0.8600, g_loss: 1.7641, q_loss: 0.0640, c_real_loss: 0.0253, c_fake_loss: 0.0047
# Epoch [6/100], Step [901/938], d_loss: 0.7754, g_loss: 1.2927, q_loss: 0.1581, c_real_loss: 0.0009, c_fake_loss: 0.0011
# Epoch [7/100], Step [1/938], d_loss: 0.9794, g_loss: 1.6390, q_loss: 0.1737, c_real_loss: 0.0374, c_fake_loss: 0.0100
# Epoch [7/100], Step [101/938], d_loss: 1.0336, g_loss: 1.5049, q_loss: 0.0605, c_real_loss: 0.0071, c_fake_loss: 0.0006
# Epoch [7/100], Step [201/938], d_loss: 0.7699, g_loss: 1.7382, q_loss: 0.1346, c_real_loss: 0.0227, c_fake_loss: 0.0013
# Epoch [7/100], Step [301/938], d_loss: 0.8055, g_loss: 1.9319, q_loss: 0.0992, c_real_loss: 0.0051, c_fake_loss: 0.0013
# Epoch [7/100], Step [401/938], d_loss: 0.8929, g_loss: 1.9052, q_loss: 0.0700, c_real_loss: 0.0016, c_fake_loss: 0.0051
# Epoch [7/100], Step [501/938], d_loss: 0.7793, g_loss: 1.8930, q_loss: 0.1373, c_real_loss: 0.0021, c_fake_loss: 0.0010
# Epoch [7/100], Step [601/938], d_loss: 0.8379, g_loss: 1.5546, q_loss: 0.0588, c_real_loss: 0.0414, c_fake_loss: 0.0028
# Epoch [7/100], Step [701/938], d_loss: 0.8766, g_loss: 1.7330, q_loss: 0.1321, c_real_loss: 0.0018, c_fake_loss: 0.0022
# Epoch [7/100], Step [801/938], d_loss: 0.9403, g_loss: 1.7925, q_loss: 0.0513, c_real_loss: 0.0113, c_fake_loss: 0.0076
# Epoch [7/100], Step [901/938], d_loss: 0.7957, g_loss: 1.5070, q_loss: 0.0550, c_real_loss: 0.0026, c_fake_loss: 0.0510
# Epoch [8/100], Step [1/938], d_loss: 0.8673, g_loss: 1.4721, q_loss: 0.1034, c_real_loss: 0.0195, c_fake_loss: 0.0025
# Epoch [8/100], Step [101/938], d_loss: 0.6759, g_loss: 1.5102, q_loss: 0.0625, c_real_loss: 0.0033, c_fake_loss: 0.0053
# Epoch [8/100], Step [201/938], d_loss: 0.8351, g_loss: 1.9634, q_loss: 0.0648, c_real_loss: 0.0026, c_fake_loss: 0.0084
# Epoch [8/100], Step [301/938], d_loss: 0.7726, g_loss: 1.8687, q_loss: 0.0849, c_real_loss: 0.0108, c_fake_loss: 0.0014
# Epoch [8/100], Step [401/938], d_loss: 0.8892, g_loss: 1.7367, q_loss: 0.0881, c_real_loss: 0.0069, c_fake_loss: 0.0008
# Epoch [8/100], Step [501/938], d_loss: 0.6936, g_loss: 1.7910, q_loss: 0.1007, c_real_loss: 0.0149, c_fake_loss: 0.0097
# Epoch [8/100], Step [601/938], d_loss: 0.8848, g_loss: 2.4280, q_loss: 0.0932, c_real_loss: 0.0042, c_fake_loss: 0.0081
# Epoch [8/100], Step [701/938], d_loss: 0.8260, g_loss: 1.6449, q_loss: 0.0604, c_real_loss: 0.0141, c_fake_loss: 0.0033
# Epoch [8/100], Step [801/938], d_loss: 0.9426, g_loss: 1.9374, q_loss: 0.1011, c_real_loss: 0.0618, c_fake_loss: 0.0033
# Epoch [8/100], Step [901/938], d_loss: 0.6972, g_loss: 1.7765, q_loss: 0.1072, c_real_loss: 0.0428, c_fake_loss: 0.0027
# Epoch [9/100], Step [1/938], d_loss: 0.8029, g_loss: 1.5253, q_loss: 0.1154, c_real_loss: 0.0092, c_fake_loss: 0.0034
# Epoch [9/100], Step [101/938], d_loss: 0.8878, g_loss: 1.5464, q_loss: 0.0628, c_real_loss: 0.0250, c_fake_loss: 0.0151
# Epoch [9/100], Step [201/938], d_loss: 0.8424, g_loss: 1.8183, q_loss: 0.0694, c_real_loss: 0.0047, c_fake_loss: 0.0063
# Epoch [9/100], Step [301/938], d_loss: 0.7780, g_loss: 1.9190, q_loss: 0.0535, c_real_loss: 0.0283, c_fake_loss: 0.0008
# Epoch [9/100], Step [401/938], d_loss: 0.9831, g_loss: 1.2141, q_loss: 0.0493, c_real_loss: 0.0008, c_fake_loss: 0.0094
# Epoch [9/100], Step [501/938], d_loss: 0.8315, g_loss: 1.7495, q_loss: 0.0815, c_real_loss: 0.0097, c_fake_loss: 0.0034
# Epoch [9/100], Step [601/938], d_loss: 1.0044, g_loss: 1.3902, q_loss: 0.1006, c_real_loss: 0.0130, c_fake_loss: 0.0227
# Epoch [9/100], Step [701/938], d_loss: 1.0064, g_loss: 2.1263, q_loss: 0.0475, c_real_loss: 0.0335, c_fake_loss: 0.0007
# Epoch [9/100], Step [801/938], d_loss: 0.8381, g_loss: 1.7911, q_loss: 0.0952, c_real_loss: 0.0170, c_fake_loss: 0.0055
# Epoch [9/100], Step [901/938], d_loss: 0.8541, g_loss: 1.8359, q_loss: 0.0646, c_real_loss: 0.0088, c_fake_loss: 0.0109
# Epoch [10/100], Step [1/938], d_loss: 0.9429, g_loss: 1.8397, q_loss: 0.0987, c_real_loss: 0.0041, c_fake_loss: 0.0009
# Epoch [10/100], Step [101/938], d_loss: 0.7894, g_loss: 1.8417, q_loss: 0.0508, c_real_loss: 0.0072, c_fake_loss: 0.0009
# Epoch [10/100], Step [201/938], d_loss: 0.8767, g_loss: 1.9081, q_loss: 0.1346, c_real_loss: 0.0446, c_fake_loss: 0.0150
# Epoch [10/100], Step [301/938], d_loss: 0.8494, g_loss: 1.7679, q_loss: 0.1144, c_real_loss: 0.0032, c_fake_loss: 0.0112
# Epoch [10/100], Step [401/938], d_loss: 1.0456, g_loss: 1.6436, q_loss: 0.0684, c_real_loss: 0.0060, c_fake_loss: 0.0003
# Epoch [10/100], Step [501/938], d_loss: 0.8375, g_loss: 1.8630, q_loss: 0.0504, c_real_loss: 0.0272, c_fake_loss: 0.0045
# Epoch [10/100], Step [601/938], d_loss: 0.7407, g_loss: 1.8870, q_loss: 0.1095, c_real_loss: 0.0056, c_fake_loss: 0.0002
# Epoch [10/100], Step [701/938], d_loss: 0.8666, g_loss: 1.8196, q_loss: 0.0712, c_real_loss: 0.0080, c_fake_loss: 0.0652
# Epoch [10/100], Step [801/938], d_loss: 0.8174, g_loss: 1.7280, q_loss: 0.1545, c_real_loss: 0.0082, c_fake_loss: 0.0013
# Epoch [10/100], Step [901/938], d_loss: 1.0430, g_loss: 1.8014, q_loss: 0.0683, c_real_loss: 0.0631, c_fake_loss: 0.0034
# Epoch [11/100], Step [1/938], d_loss: 1.2729, g_loss: 1.9840, q_loss: 0.1057, c_real_loss: 0.0052, c_fake_loss: 0.0212
# Epoch [11/100], Step [101/938], d_loss: 0.9079, g_loss: 1.9825, q_loss: 0.2838, c_real_loss: 0.0019, c_fake_loss: 0.0046
# Epoch [11/100], Step [201/938], d_loss: 0.7508, g_loss: 1.4961, q_loss: 0.0370, c_real_loss: 0.0096, c_fake_loss: 0.0007
# Epoch [11/100], Step [301/938], d_loss: 0.9757, g_loss: 1.4315, q_loss: 0.0714, c_real_loss: 0.0005, c_fake_loss: 0.0033
# Epoch [11/100], Step [401/938], d_loss: 0.7500, g_loss: 1.7954, q_loss: 0.0960, c_real_loss: 0.0015, c_fake_loss: 0.0035
# Epoch [11/100], Step [501/938], d_loss: 0.8576, g_loss: 1.3563, q_loss: 0.0560, c_real_loss: 0.0200, c_fake_loss: 0.0009
# Epoch [11/100], Step [601/938], d_loss: 1.0094, g_loss: 1.8642, q_loss: 0.0576, c_real_loss: 0.0105, c_fake_loss: 0.0008
# Epoch [11/100], Step [701/938], d_loss: 1.0474, g_loss: 1.4479, q_loss: 0.0399, c_real_loss: 0.0108, c_fake_loss: 0.0017
# Epoch [11/100], Step [801/938], d_loss: 0.8795, g_loss: 1.7565, q_loss: 0.0585, c_real_loss: 0.0114, c_fake_loss: 0.0004
# Epoch [11/100], Step [901/938], d_loss: 0.6198, g_loss: 1.7973, q_loss: 0.0638, c_real_loss: 0.0031, c_fake_loss: 0.0005
# Epoch [12/100], Step [1/938], d_loss: 0.7462, g_loss: 1.6747, q_loss: 0.1138, c_real_loss: 0.0164, c_fake_loss: 0.0081
# Epoch [12/100], Step [101/938], d_loss: 0.8134, g_loss: 1.9407, q_loss: 0.1173, c_real_loss: 0.0157, c_fake_loss: 0.0002
# Epoch [12/100], Step [201/938], d_loss: 0.8196, g_loss: 1.7249, q_loss: 0.0811, c_real_loss: 0.0265, c_fake_loss: 0.0009
# Epoch [12/100], Step [301/938], d_loss: 0.6794, g_loss: 1.8510, q_loss: 0.0864, c_real_loss: 0.0088, c_fake_loss: 0.0013
# Epoch [12/100], Step [401/938], d_loss: 0.7754, g_loss: 1.5497, q_loss: 0.0522, c_real_loss: 0.0122, c_fake_loss: 0.0002
# Epoch [12/100], Step [501/938], d_loss: 0.7041, g_loss: 1.7273, q_loss: 0.1162, c_real_loss: 0.0218, c_fake_loss: 0.0002
# Epoch [12/100], Step [601/938], d_loss: 0.9148, g_loss: 1.7267, q_loss: 0.1406, c_real_loss: 0.0145, c_fake_loss: 0.0012
# Epoch [12/100], Step [701/938], d_loss: 0.6418, g_loss: 2.0536, q_loss: 0.0836, c_real_loss: 0.0065, c_fake_loss: 0.0275
# Epoch [12/100], Step [801/938], d_loss: 0.9603, g_loss: 1.8300, q_loss: 0.0764, c_real_loss: 0.0828, c_fake_loss: 0.0015
# Epoch [12/100], Step [901/938], d_loss: 0.7637, g_loss: 2.1245, q_loss: 0.2012, c_real_loss: 0.0028, c_fake_loss: 0.0118
# Epoch [13/100], Step [1/938], d_loss: 1.0270, g_loss: 1.9312, q_loss: 0.0501, c_real_loss: 0.0063, c_fake_loss: 0.0008
# Epoch [13/100], Step [101/938], d_loss: 0.7767, g_loss: 1.9599, q_loss: 0.0340, c_real_loss: 0.0034, c_fake_loss: 0.0207
# Epoch [13/100], Step [201/938], d_loss: 0.9715, g_loss: 1.5272, q_loss: 0.0594, c_real_loss: 0.0256, c_fake_loss: 0.0011
# Epoch [13/100], Step [301/938], d_loss: 0.6598, g_loss: 1.8887, q_loss: 0.0429, c_real_loss: 0.0085, c_fake_loss: 0.0041
# Epoch [13/100], Step [401/938], d_loss: 0.8372, g_loss: 2.0499, q_loss: 0.1211, c_real_loss: 0.0967, c_fake_loss: 0.0028
# Epoch [13/100], Step [501/938], d_loss: 0.8683, g_loss: 1.7274, q_loss: 0.1211, c_real_loss: 0.0278, c_fake_loss: 0.0020
# Epoch [13/100], Step [601/938], d_loss: 0.7071, g_loss: 1.9674, q_loss: 0.0362, c_real_loss: 0.0081, c_fake_loss: 0.0006
# Epoch [13/100], Step [701/938], d_loss: 0.7945, g_loss: 1.9481, q_loss: 0.0749, c_real_loss: 0.0205, c_fake_loss: 0.0010
# Epoch [13/100], Step [801/938], d_loss: 0.8703, g_loss: 1.7290, q_loss: 0.0894, c_real_loss: 0.0039, c_fake_loss: 0.0605
# Epoch [13/100], Step [901/938], d_loss: 0.7888, g_loss: 1.8395, q_loss: 0.1294, c_real_loss: 0.0080, c_fake_loss: 0.0016
# Epoch [14/100], Step [1/938], d_loss: 0.7825, g_loss: 2.3673, q_loss: 0.1592, c_real_loss: 0.0022, c_fake_loss: 0.0005
# Epoch [14/100], Step [101/938], d_loss: 0.8914, g_loss: 1.9026, q_loss: 0.0764, c_real_loss: 0.0021, c_fake_loss: 0.0033
# Epoch [14/100], Step [201/938], d_loss: 0.7657, g_loss: 1.8073, q_loss: 0.1253, c_real_loss: 0.0006, c_fake_loss: 0.0328
# Epoch [14/100], Step [301/938], d_loss: 0.9463, g_loss: 2.1985, q_loss: 0.0974, c_real_loss: 0.0037, c_fake_loss: 0.0004
# Epoch [14/100], Step [401/938], d_loss: 0.7476, g_loss: 1.6385, q_loss: 0.1166, c_real_loss: 0.0147, c_fake_loss: 0.0036
# Epoch [14/100], Step [501/938], d_loss: 0.7703, g_loss: 1.7595, q_loss: 0.0347, c_real_loss: 0.0050, c_fake_loss: 0.0007
# Epoch [14/100], Step [601/938], d_loss: 0.7082, g_loss: 2.0331, q_loss: 0.2457, c_real_loss: 0.0324, c_fake_loss: 0.0007
# Epoch [14/100], Step [701/938], d_loss: 0.8399, g_loss: 1.9550, q_loss: 0.0458, c_real_loss: 0.0054, c_fake_loss: 0.0006
# Epoch [14/100], Step [801/938], d_loss: 0.8165, g_loss: 2.1597, q_loss: 0.0914, c_real_loss: 0.0018, c_fake_loss: 0.0409
# Epoch [14/100], Step [901/938], d_loss: 0.9787, g_loss: 1.6656, q_loss: 0.1896, c_real_loss: 0.0213, c_fake_loss: 0.0054
# Epoch [15/100], Step [1/938], d_loss: 0.7529, g_loss: 2.1092, q_loss: 0.0792, c_real_loss: 0.0150, c_fake_loss: 0.0235
# Epoch [15/100], Step [101/938], d_loss: 0.8117, g_loss: 2.4720, q_loss: 0.2134, c_real_loss: 0.0012, c_fake_loss: 0.0023
# Epoch [15/100], Step [201/938], d_loss: 0.8002, g_loss: 2.2876, q_loss: 0.0439, c_real_loss: 0.0046, c_fake_loss: 0.0054
# Epoch [15/100], Step [301/938], d_loss: 0.8114, g_loss: 1.9402, q_loss: 0.1873, c_real_loss: 0.0017, c_fake_loss: 0.0252
# Epoch [15/100], Step [401/938], d_loss: 0.8690, g_loss: 2.0338, q_loss: 0.0513, c_real_loss: 0.0022, c_fake_loss: 0.0001
# Epoch [15/100], Step [501/938], d_loss: 0.7330, g_loss: 1.6219, q_loss: 0.0307, c_real_loss: 0.0125, c_fake_loss: 0.0263
# Epoch [15/100], Step [601/938], d_loss: 0.9035, g_loss: 1.6910, q_loss: 0.0295, c_real_loss: 0.0103, c_fake_loss: 0.0003
# Epoch [15/100], Step [701/938], d_loss: 0.6743, g_loss: 2.0407, q_loss: 0.0672, c_real_loss: 0.0035, c_fake_loss: 0.0025
# Epoch [15/100], Step [801/938], d_loss: 0.6713, g_loss: 2.0367, q_loss: 0.1029, c_real_loss: 0.0104, c_fake_loss: 0.0002
# Epoch [15/100], Step [901/938], d_loss: 0.7473, g_loss: 1.9023, q_loss: 0.0464, c_real_loss: 0.0009, c_fake_loss: 0.0027
# Epoch [16/100], Step [1/938], d_loss: 0.6723, g_loss: 2.3610, q_loss: 0.0473, c_real_loss: 0.0020, c_fake_loss: 0.0018
# Epoch [16/100], Step [101/938], d_loss: 0.9759, g_loss: 1.7983, q_loss: 0.1330, c_real_loss: 0.0135, c_fake_loss: 0.0147
# Epoch [16/100], Step [201/938], d_loss: 0.6692, g_loss: 1.5996, q_loss: 0.0445, c_real_loss: 0.0054, c_fake_loss: 0.0002
# Epoch [16/100], Step [301/938], d_loss: 0.7023, g_loss: 2.1380, q_loss: 0.0558, c_real_loss: 0.0054, c_fake_loss: 0.0004
# Epoch [16/100], Step [401/938], d_loss: 0.5095, g_loss: 2.2723, q_loss: 0.0917, c_real_loss: 0.0216, c_fake_loss: 0.0307
# Epoch [16/100], Step [501/938], d_loss: 0.7083, g_loss: 1.9102, q_loss: 0.0479, c_real_loss: 0.0062, c_fake_loss: 0.0002
# Epoch [16/100], Step [601/938], d_loss: 0.8701, g_loss: 1.9777, q_loss: 0.2767, c_real_loss: 0.0542, c_fake_loss: 0.0043
# Epoch [16/100], Step [701/938], d_loss: 0.9145, g_loss: 2.0226, q_loss: 0.0437, c_real_loss: 0.0023, c_fake_loss: 0.0009
# Epoch [16/100], Step [801/938], d_loss: 0.7714, g_loss: 1.8654, q_loss: 0.0456, c_real_loss: 0.0177, c_fake_loss: 0.0013
# Epoch [16/100], Step [901/938], d_loss: 0.8755, g_loss: 2.0072, q_loss: 0.1547, c_real_loss: 0.0391, c_fake_loss: 0.0231
# Epoch [17/100], Step [1/938], d_loss: 0.9256, g_loss: 2.0505, q_loss: 0.0989, c_real_loss: 0.0030, c_fake_loss: 0.0055
# Epoch [17/100], Step [101/938], d_loss: 0.8723, g_loss: 1.7052, q_loss: 0.0633, c_real_loss: 0.0041, c_fake_loss: 0.0008
# Epoch [17/100], Step [201/938], d_loss: 0.7203, g_loss: 1.5790, q_loss: 0.0421, c_real_loss: 0.0011, c_fake_loss: 0.0003
# Epoch [17/100], Step [301/938], d_loss: 0.8625, g_loss: 1.8944, q_loss: 0.0979, c_real_loss: 0.0273, c_fake_loss: 0.0001
# Epoch [17/100], Step [401/938], d_loss: 0.7249, g_loss: 2.2426, q_loss: 0.0559, c_real_loss: 0.0609, c_fake_loss: 0.0037
# Epoch [17/100], Step [501/938], d_loss: 0.5791, g_loss: 2.3181, q_loss: 0.0416, c_real_loss: 0.0062, c_fake_loss: 0.0004
# Epoch [17/100], Step [601/938], d_loss: 0.9141, g_loss: 1.6287, q_loss: 0.0581, c_real_loss: 0.0004, c_fake_loss: 0.0008
# Epoch [17/100], Step [701/938], d_loss: 0.7250, g_loss: 1.7216, q_loss: 0.0399, c_real_loss: 0.0015, c_fake_loss: 0.0005
# Epoch [17/100], Step [801/938], d_loss: 0.6659, g_loss: 2.0038, q_loss: 0.1422, c_real_loss: 0.0023, c_fake_loss: 0.0008
# Epoch [17/100], Step [901/938], d_loss: 0.9013, g_loss: 2.5727, q_loss: 0.0577, c_real_loss: 0.0073, c_fake_loss: 0.0001
# Epoch [18/100], Step [1/938], d_loss: 1.0112, g_loss: 2.2702, q_loss: 0.1851, c_real_loss: 0.0100, c_fake_loss: 0.0031
# Epoch [18/100], Step [101/938], d_loss: 0.8659, g_loss: 1.8061, q_loss: 0.0783, c_real_loss: 0.0041, c_fake_loss: 0.0037
# Epoch [18/100], Step [201/938], d_loss: 0.6490, g_loss: 2.2171, q_loss: 0.0658, c_real_loss: 0.0016, c_fake_loss: 0.0001
# Epoch [18/100], Step [301/938], d_loss: 0.7378, g_loss: 2.1894, q_loss: 0.0972, c_real_loss: 0.0090, c_fake_loss: 0.0003
# Epoch [18/100], Step [401/938], d_loss: 0.7720, g_loss: 2.3268, q_loss: 0.0907, c_real_loss: 0.0049, c_fake_loss: 0.0026
# Epoch [18/100], Step [501/938], d_loss: 0.6355, g_loss: 1.9632, q_loss: 0.0730, c_real_loss: 0.0024, c_fake_loss: 0.0001
# Epoch [18/100], Step [601/938], d_loss: 0.6854, g_loss: 2.0777, q_loss: 0.0313, c_real_loss: 0.0027, c_fake_loss: 0.0002
# Epoch [18/100], Step [701/938], d_loss: 0.6316, g_loss: 1.5666, q_loss: 0.0656, c_real_loss: 0.0035, c_fake_loss: 0.0004
# Epoch [18/100], Step [801/938], d_loss: 0.7803, g_loss: 1.5486, q_loss: 0.0485, c_real_loss: 0.0080, c_fake_loss: 0.0016
# Epoch [18/100], Step [901/938], d_loss: 0.7502, g_loss: 2.2287, q_loss: 0.0818, c_real_loss: 0.0045, c_fake_loss: 0.0008
# Epoch [19/100], Step [1/938], d_loss: 0.8741, g_loss: 2.6415, q_loss: 0.4624, c_real_loss: 0.0021, c_fake_loss: 0.0002
# Epoch [19/100], Step [101/938], d_loss: 0.8418, g_loss: 1.4638, q_loss: 0.0657, c_real_loss: 0.0059, c_fake_loss: 0.0007
# Epoch [19/100], Step [201/938], d_loss: 0.9742, g_loss: 2.1688, q_loss: 0.1409, c_real_loss: 0.0007, c_fake_loss: 0.0005
# Epoch [19/100], Step [301/938], d_loss: 0.5567, g_loss: 1.7632, q_loss: 0.0379, c_real_loss: 0.0233, c_fake_loss: 0.0002
# Epoch [19/100], Step [401/938], d_loss: 0.8633, g_loss: 1.7214, q_loss: 0.0379, c_real_loss: 0.0009, c_fake_loss: 0.0008
# Epoch [19/100], Step [501/938], d_loss: 0.9260, g_loss: 1.6701, q_loss: 0.1052, c_real_loss: 0.0038, c_fake_loss: 0.0002
# Epoch [19/100], Step [601/938], d_loss: 0.9335, g_loss: 1.6108, q_loss: 0.0457, c_real_loss: 0.0100, c_fake_loss: 0.0009
# Epoch [19/100], Step [701/938], d_loss: 0.7616, g_loss: 1.7792, q_loss: 0.0323, c_real_loss: 0.0062, c_fake_loss: 0.0004
# Epoch [19/100], Step [801/938], d_loss: 0.7936, g_loss: 2.1795, q_loss: 0.0988, c_real_loss: 0.0068, c_fake_loss: 0.0053
# Epoch [19/100], Step [901/938], d_loss: 0.7189, g_loss: 1.9826, q_loss: 0.0316, c_real_loss: 0.0012, c_fake_loss: 0.0017
# Epoch [20/100], Step [1/938], d_loss: 0.7929, g_loss: 1.8051, q_loss: 0.0658, c_real_loss: 0.0080, c_fake_loss: 0.0001
# Epoch [20/100], Step [101/938], d_loss: 0.6267, g_loss: 1.9246, q_loss: 0.0498, c_real_loss: 0.0008, c_fake_loss: 0.0005
# Epoch [20/100], Step [201/938], d_loss: 0.8492, g_loss: 1.9305, q_loss: 0.0500, c_real_loss: 0.0001, c_fake_loss: 0.0003
# Epoch [20/100], Step [301/938], d_loss: 0.8645, g_loss: 1.8874, q_loss: 0.1132, c_real_loss: 0.0006, c_fake_loss: 0.0002
# Epoch [20/100], Step [401/938], d_loss: 0.6958, g_loss: 2.4377, q_loss: 0.0489, c_real_loss: 0.0159, c_fake_loss: 0.0002
# Epoch [20/100], Step [501/938], d_loss: 0.6932, g_loss: 2.4593, q_loss: 0.1440, c_real_loss: 0.0032, c_fake_loss: 0.0010
# Epoch [20/100], Step [601/938], d_loss: 1.2017, g_loss: 2.0277, q_loss: 0.0992, c_real_loss: 0.0017, c_fake_loss: 0.0001
# Epoch [20/100], Step [701/938], d_loss: 0.7002, g_loss: 1.9921, q_loss: 0.0698, c_real_loss: 0.0012, c_fake_loss: 0.0001
# Epoch [20/100], Step [801/938], d_loss: 0.7799, g_loss: 2.0750, q_loss: 0.1600, c_real_loss: 0.0064, c_fake_loss: 0.0017
# Epoch [20/100], Step [901/938], d_loss: 0.7658, g_loss: 1.4961, q_loss: 0.0256, c_real_loss: 0.0074, c_fake_loss: 0.0001
# Epoch [21/100], Step [1/938], d_loss: 0.7919, g_loss: 2.3459, q_loss: 0.0705, c_real_loss: 0.0077, c_fake_loss: 0.0013
# Epoch [21/100], Step [101/938], d_loss: 0.6168, g_loss: 2.0814, q_loss: 0.0562, c_real_loss: 0.0010, c_fake_loss: 0.0197
# Epoch [21/100], Step [201/938], d_loss: 0.7930, g_loss: 1.8792, q_loss: 0.0743, c_real_loss: 0.0033, c_fake_loss: 0.0005
# Epoch [21/100], Step [301/938], d_loss: 0.5830, g_loss: 2.4692, q_loss: 0.0655, c_real_loss: 0.0028, c_fake_loss: 0.0009
# Epoch [21/100], Step [401/938], d_loss: 0.8489, g_loss: 1.8929, q_loss: 0.1027, c_real_loss: 0.0104, c_fake_loss: 0.0025
# Epoch [21/100], Step [501/938], d_loss: 0.8044, g_loss: 1.6898, q_loss: 0.0438, c_real_loss: 0.0065, c_fake_loss: 0.0006
# Epoch [21/100], Step [601/938], d_loss: 0.6470, g_loss: 1.9304, q_loss: 0.1354, c_real_loss: 0.0007, c_fake_loss: 0.0014
# Epoch [21/100], Step [701/938], d_loss: 0.7600, g_loss: 2.1581, q_loss: 0.0603, c_real_loss: 0.0030, c_fake_loss: 0.0250
# Epoch [21/100], Step [801/938], d_loss: 0.6157, g_loss: 2.1421, q_loss: 0.0727, c_real_loss: 0.0042, c_fake_loss: 0.0008
# Epoch [21/100], Step [901/938], d_loss: 0.8665, g_loss: 2.3462, q_loss: 0.0525, c_real_loss: 0.0491, c_fake_loss: 0.0047
# Epoch [22/100], Step [1/938], d_loss: 0.6242, g_loss: 2.3478, q_loss: 0.0296, c_real_loss: 0.0021, c_fake_loss: 0.0009
# Epoch [22/100], Step [101/938], d_loss: 0.7158, g_loss: 2.4438, q_loss: 0.1003, c_real_loss: 0.0005, c_fake_loss: 0.0001
# Epoch [22/100], Step [201/938], d_loss: 0.7213, g_loss: 2.4249, q_loss: 0.1521, c_real_loss: 0.0026, c_fake_loss: 0.0007
# Epoch [22/100], Step [301/938], d_loss: 0.6568, g_loss: 2.0520, q_loss: 0.0725, c_real_loss: 0.0078, c_fake_loss: 0.0002
# Epoch [22/100], Step [401/938], d_loss: 0.5130, g_loss: 1.9129, q_loss: 0.0264, c_real_loss: 0.0008, c_fake_loss: 0.0004
# Epoch [22/100], Step [501/938], d_loss: 0.9133, g_loss: 2.1559, q_loss: 0.1712, c_real_loss: 0.0134, c_fake_loss: 0.0341
# Epoch [22/100], Step [601/938], d_loss: 0.6755, g_loss: 2.4677, q_loss: 0.0512, c_real_loss: 0.0036, c_fake_loss: 0.0001
# Epoch [22/100], Step [701/938], d_loss: 0.6539, g_loss: 2.1578, q_loss: 0.0518, c_real_loss: 0.0094, c_fake_loss: 0.0453
# Epoch [22/100], Step [801/938], d_loss: 0.6302, g_loss: 2.2190, q_loss: 0.0590, c_real_loss: 0.0037, c_fake_loss: 0.0000
# Epoch [22/100], Step [901/938], d_loss: 0.6022, g_loss: 1.9718, q_loss: 0.1095, c_real_loss: 0.0024, c_fake_loss: 0.0001
# Epoch [23/100], Step [1/938], d_loss: 0.7359, g_loss: 2.2775, q_loss: 0.0515, c_real_loss: 0.0017, c_fake_loss: 0.0307
# Epoch [23/100], Step [101/938], d_loss: 0.5945, g_loss: 2.2647, q_loss: 0.1357, c_real_loss: 0.0019, c_fake_loss: 0.0033
# Epoch [23/100], Step [201/938], d_loss: 0.5544, g_loss: 2.2877, q_loss: 0.0311, c_real_loss: 0.0042, c_fake_loss: 0.0010
# Epoch [23/100], Step [301/938], d_loss: 0.6606, g_loss: 2.1641, q_loss: 0.0213, c_real_loss: 0.0004, c_fake_loss: 0.0018
# Epoch [23/100], Step [401/938], d_loss: 0.6454, g_loss: 1.9933, q_loss: 0.1028, c_real_loss: 0.0185, c_fake_loss: 0.0008
# Epoch [23/100], Step [501/938], d_loss: 0.5499, g_loss: 2.5364, q_loss: 0.0392, c_real_loss: 0.0005, c_fake_loss: 0.0004
# Epoch [23/100], Step [601/938], d_loss: 0.6507, g_loss: 1.9291, q_loss: 0.0375, c_real_loss: 0.0007, c_fake_loss: 0.0007
# Epoch [23/100], Step [701/938], d_loss: 1.0315, g_loss: 2.0438, q_loss: 0.0673, c_real_loss: 0.0010, c_fake_loss: 0.0004
# Epoch [23/100], Step [801/938], d_loss: 0.6487, g_loss: 2.5606, q_loss: 0.0870, c_real_loss: 0.0004, c_fake_loss: 0.0006
# Epoch [23/100], Step [901/938], d_loss: 0.6784, g_loss: 1.4975, q_loss: 0.0525, c_real_loss: 0.0008, c_fake_loss: 0.0001
# Epoch [24/100], Step [1/938], d_loss: 0.7139, g_loss: 2.0891, q_loss: 0.0924, c_real_loss: 0.0027, c_fake_loss: 0.0205
# Epoch [24/100], Step [101/938], d_loss: 0.5763, g_loss: 2.6645, q_loss: 0.0450, c_real_loss: 0.0011, c_fake_loss: 0.0163
# Epoch [24/100], Step [201/938], d_loss: 0.5665, g_loss: 1.9744, q_loss: 0.1127, c_real_loss: 0.0029, c_fake_loss: 0.0001
# Epoch [24/100], Step [301/938], d_loss: 0.7687, g_loss: 1.7034, q_loss: 0.0273, c_real_loss: 0.0139, c_fake_loss: 0.0013
# Epoch [24/100], Step [401/938], d_loss: 0.6881, g_loss: 1.9246, q_loss: 0.0648, c_real_loss: 0.0056, c_fake_loss: 0.0004
# Epoch [24/100], Step [501/938], d_loss: 0.4660, g_loss: 2.2390, q_loss: 0.0274, c_real_loss: 0.0044, c_fake_loss: 0.0002
# Epoch [24/100], Step [601/938], d_loss: 0.5754, g_loss: 2.5383, q_loss: 0.1449, c_real_loss: 0.0015, c_fake_loss: 0.0054
# Epoch [24/100], Step [701/938], d_loss: 0.6116, g_loss: 2.3795, q_loss: 0.0823, c_real_loss: 0.0039, c_fake_loss: 0.0003
# Epoch [24/100], Step [801/938], d_loss: 0.8653, g_loss: 2.3710, q_loss: 0.0838, c_real_loss: 0.0173, c_fake_loss: 0.0002
# Epoch [24/100], Step [901/938], d_loss: 0.8093, g_loss: 1.5477, q_loss: 0.0466, c_real_loss: 0.0008, c_fake_loss: 0.0047
# Epoch [25/100], Step [1/938], d_loss: 0.5880, g_loss: 2.3213, q_loss: 0.0461, c_real_loss: 0.0016, c_fake_loss: 0.0048
# Epoch [25/100], Step [101/938], d_loss: 0.7079, g_loss: 1.8121, q_loss: 0.0476, c_real_loss: 0.0170, c_fake_loss: 0.0011
# Epoch [25/100], Step [201/938], d_loss: 0.6934, g_loss: 1.9111, q_loss: 0.0379, c_real_loss: 0.0015, c_fake_loss: 0.0001
# Epoch [25/100], Step [301/938], d_loss: 0.5569, g_loss: 2.4260, q_loss: 0.1300, c_real_loss: 0.0003, c_fake_loss: 0.0001
# Epoch [25/100], Step [401/938], d_loss: 0.4896, g_loss: 2.4422, q_loss: 0.0510, c_real_loss: 0.0068, c_fake_loss: 0.0001
# Epoch [25/100], Step [501/938], d_loss: 0.5604, g_loss: 2.0501, q_loss: 0.0544, c_real_loss: 0.0019, c_fake_loss: 0.0008
# Epoch [25/100], Step [601/938], d_loss: 0.6887, g_loss: 2.3842, q_loss: 0.0349, c_real_loss: 0.0017, c_fake_loss: 0.0029
# Epoch [25/100], Step [701/938], d_loss: 0.6857, g_loss: 2.2654, q_loss: 0.0296, c_real_loss: 0.0010, c_fake_loss: 0.0001
# Epoch [25/100], Step [801/938], d_loss: 0.5930, g_loss: 2.5571, q_loss: 0.0373, c_real_loss: 0.0006, c_fake_loss: 0.0009
# Epoch [25/100], Step [901/938], d_loss: 0.7459, g_loss: 3.0675, q_loss: 0.0593, c_real_loss: 0.0183, c_fake_loss: 0.0000
# Epoch [26/100], Step [1/938], d_loss: 0.7738, g_loss: 2.3108, q_loss: 0.1251, c_real_loss: 0.0017, c_fake_loss: 0.0012
# Epoch [26/100], Step [101/938], d_loss: 0.7807, g_loss: 1.8562, q_loss: 0.0440, c_real_loss: 0.0001, c_fake_loss: 0.0000
# Epoch [26/100], Step [201/938], d_loss: 0.8881, g_loss: 1.8030, q_loss: 0.0908, c_real_loss: 0.0006, c_fake_loss: 0.0002
# Epoch [26/100], Step [301/938], d_loss: 0.5103, g_loss: 2.1575, q_loss: 0.0848, c_real_loss: 0.0052, c_fake_loss: 0.0000
# Epoch [26/100], Step [401/938], d_loss: 0.6811, g_loss: 2.2672, q_loss: 0.0649, c_real_loss: 0.0137, c_fake_loss: 0.0003
# Epoch [26/100], Step [501/938], d_loss: 0.6542, g_loss: 2.5119, q_loss: 0.0658, c_real_loss: 0.0050, c_fake_loss: 0.0109
# Epoch [26/100], Step [601/938], d_loss: 0.6143, g_loss: 1.8106, q_loss: 0.0248, c_real_loss: 0.0010, c_fake_loss: 0.0004
# Epoch [26/100], Step [701/938], d_loss: 0.5670, g_loss: 2.4602, q_loss: 0.0599, c_real_loss: 0.0194, c_fake_loss: 0.0007
# Epoch [26/100], Step [801/938], d_loss: 0.5477, g_loss: 2.2158, q_loss: 0.0746, c_real_loss: 0.0023, c_fake_loss: 0.0003
# Epoch [26/100], Step [901/938], d_loss: 0.5051, g_loss: 2.1241, q_loss: 0.0321, c_real_loss: 0.0009, c_fake_loss: 0.0003
# Epoch [27/100], Step [1/938], d_loss: 0.6949, g_loss: 2.1493, q_loss: 0.0215, c_real_loss: 0.0002, c_fake_loss: 0.0033
# Epoch [27/100], Step [101/938], d_loss: 0.7331, g_loss: 2.2961, q_loss: 0.0933, c_real_loss: 0.0003, c_fake_loss: 0.0000
# Epoch [27/100], Step [201/938], d_loss: 0.5451, g_loss: 2.5872, q_loss: 0.0757, c_real_loss: 0.0051, c_fake_loss: 0.0008
# Epoch [27/100], Step [301/938], d_loss: 0.6674, g_loss: 2.4171, q_loss: 0.0373, c_real_loss: 0.0127, c_fake_loss: 0.0003
# Epoch [27/100], Step [401/938], d_loss: 0.7651, g_loss: 2.8227, q_loss: 0.0344, c_real_loss: 0.0111, c_fake_loss: 0.0019
# Epoch [27/100], Step [501/938], d_loss: 0.5405, g_loss: 2.3759, q_loss: 0.0438, c_real_loss: 0.0010, c_fake_loss: 0.0006
# Epoch [27/100], Step [601/938], d_loss: 0.7859, g_loss: 2.0752, q_loss: 0.0282, c_real_loss: 0.0017, c_fake_loss: 0.0002
# Epoch [27/100], Step [701/938], d_loss: 0.6860, g_loss: 2.3967, q_loss: 0.0393, c_real_loss: 0.0062, c_fake_loss: 0.0005
# Epoch [27/100], Step [801/938], d_loss: 0.5797, g_loss: 2.5042, q_loss: 0.0264, c_real_loss: 0.0004, c_fake_loss: 0.0001
# Epoch [27/100], Step [901/938], d_loss: 0.5437, g_loss: 2.8429, q_loss: 0.0510, c_real_loss: 0.0010, c_fake_loss: 0.0005
# Epoch [28/100], Step [1/938], d_loss: 0.6776, g_loss: 2.7680, q_loss: 0.1095, c_real_loss: 0.0008, c_fake_loss: 0.0002
# Epoch [28/100], Step [101/938], d_loss: 0.6910, g_loss: 2.2060, q_loss: 0.0521, c_real_loss: 0.0010, c_fake_loss: 0.0002
# Epoch [28/100], Step [201/938], d_loss: 0.6462, g_loss: 2.1070, q_loss: 0.0371, c_real_loss: 0.0008, c_fake_loss: 0.0004
# Epoch [28/100], Step [301/938], d_loss: 0.5781, g_loss: 2.2219, q_loss: 0.0708, c_real_loss: 0.0019, c_fake_loss: 0.0002
# Epoch [28/100], Step [401/938], d_loss: 0.6595, g_loss: 2.3352, q_loss: 0.0784, c_real_loss: 0.0125, c_fake_loss: 0.0399
# Epoch [28/100], Step [501/938], d_loss: 0.6341, g_loss: 2.3522, q_loss: 0.1446, c_real_loss: 0.0009, c_fake_loss: 0.0283
# Epoch [28/100], Step [601/938], d_loss: 0.5237, g_loss: 2.3937, q_loss: 0.0622, c_real_loss: 0.0004, c_fake_loss: 0.0081
# Epoch [28/100], Step [701/938], d_loss: 0.5184, g_loss: 2.1656, q_loss: 0.0954, c_real_loss: 0.0010, c_fake_loss: 0.0003
# Epoch [28/100], Step [801/938], d_loss: 0.6153, g_loss: 1.8793, q_loss: 0.0266, c_real_loss: 0.0027, c_fake_loss: 0.0003
# Epoch [28/100], Step [901/938], d_loss: 0.5606, g_loss: 2.2906, q_loss: 0.0303, c_real_loss: 0.0038, c_fake_loss: 0.0000
# Epoch [29/100], Step [1/938], d_loss: 0.7066, g_loss: 2.8794, q_loss: 0.0436, c_real_loss: 0.0010, c_fake_loss: 0.0017
# Epoch [29/100], Step [101/938], d_loss: 0.4802, g_loss: 2.2501, q_loss: 0.0467, c_real_loss: 0.0002, c_fake_loss: 0.0005
# Epoch [29/100], Step [201/938], d_loss: 0.5014, g_loss: 2.2616, q_loss: 0.0341, c_real_loss: 0.0021, c_fake_loss: 0.0001
# Epoch [29/100], Step [301/938], d_loss: 0.4438, g_loss: 3.0875, q_loss: 0.0409, c_real_loss: 0.0051, c_fake_loss: 0.0020
# Epoch [29/100], Step [401/938], d_loss: 0.6811, g_loss: 2.4942, q_loss: 0.0743, c_real_loss: 0.0009, c_fake_loss: 0.0004
# Epoch [29/100], Step [501/938], d_loss: 0.4996, g_loss: 2.3504, q_loss: 0.0947, c_real_loss: 0.0032, c_fake_loss: 0.0001
# Epoch [29/100], Step [601/938], d_loss: 0.6692, g_loss: 2.7011, q_loss: 0.1423, c_real_loss: 0.0004, c_fake_loss: 0.0009
# Epoch [29/100], Step [701/938], d_loss: 0.5826, g_loss: 2.5089, q_loss: 0.1049, c_real_loss: 0.0004, c_fake_loss: 0.0173
# Epoch [29/100], Step [801/938], d_loss: 0.4650, g_loss: 3.2059, q_loss: 0.0244, c_real_loss: 0.0044, c_fake_loss: 0.0428
# Epoch [29/100], Step [901/938], d_loss: 0.4980, g_loss: 1.9187, q_loss: 0.0824, c_real_loss: 0.0048, c_fake_loss: 0.0001
# Epoch [30/100], Step [1/938], d_loss: 0.7818, g_loss: 2.6674, q_loss: 0.1276, c_real_loss: 0.0199, c_fake_loss: 0.0002
# Epoch [30/100], Step [101/938], d_loss: 0.5179, g_loss: 2.1206, q_loss: 0.1308, c_real_loss: 0.0007, c_fake_loss: 0.0001
# Epoch [30/100], Step [201/938], d_loss: 0.7373, g_loss: 2.6165, q_loss: 0.0573, c_real_loss: 0.0834, c_fake_loss: 0.0001
# Epoch [30/100], Step [301/938], d_loss: 0.8516, g_loss: 3.0473, q_loss: 0.0299, c_real_loss: 0.0005, c_fake_loss: 0.0005
# Epoch [30/100], Step [401/938], d_loss: 0.6530, g_loss: 2.4114, q_loss: 0.0474, c_real_loss: 0.0016, c_fake_loss: 0.0001
# Epoch [30/100], Step [501/938], d_loss: 0.5292, g_loss: 2.1201, q_loss: 0.0621, c_real_loss: 0.0001, c_fake_loss: 0.0002
# Epoch [30/100], Step [601/938], d_loss: 0.5759, g_loss: 2.3616, q_loss: 0.0344, c_real_loss: 0.0012, c_fake_loss: 0.0066
# Epoch [30/100], Step [701/938], d_loss: 0.5204, g_loss: 2.6257, q_loss: 0.1241, c_real_loss: 0.0010, c_fake_loss: 0.0002
# Epoch [30/100], Step [801/938], d_loss: 0.5187, g_loss: 2.7787, q_loss: 0.1513, c_real_loss: 0.0011, c_fake_loss: 0.0001
# Epoch [30/100], Step [901/938], d_loss: 0.6091, g_loss: 2.5121, q_loss: 0.0247, c_real_loss: 0.0020, c_fake_loss: 0.0001
# Epoch [31/100], Step [1/938], d_loss: 0.6669, g_loss: 1.6962, q_loss: 0.0878, c_real_loss: 0.0042, c_fake_loss: 0.0005
# Epoch [31/100], Step [101/938], d_loss: 0.5565, g_loss: 2.4726, q_loss: 0.2415, c_real_loss: 0.0053, c_fake_loss: 0.0058
# Epoch [31/100], Step [201/938], d_loss: 0.5628, g_loss: 2.8131, q_loss: 0.1700, c_real_loss: 0.0003, c_fake_loss: 0.0002
# Epoch [31/100], Step [301/938], d_loss: 0.5806, g_loss: 2.1221, q_loss: 0.0250, c_real_loss: 0.0033, c_fake_loss: 0.0002
# Epoch [31/100], Step [401/938], d_loss: 1.1118, g_loss: 1.9472, q_loss: 0.2330, c_real_loss: 0.0006, c_fake_loss: 0.0001
# Epoch [31/100], Step [501/938], d_loss: 0.6718, g_loss: 2.5660, q_loss: 0.0886, c_real_loss: 0.0012, c_fake_loss: 0.0001
# Epoch [31/100], Step [601/938], d_loss: 0.5259, g_loss: 2.1953, q_loss: 0.0563, c_real_loss: 0.0312, c_fake_loss: 0.0001
# Epoch [31/100], Step [701/938], d_loss: 0.6206, g_loss: 2.1561, q_loss: 0.0516, c_real_loss: 0.0010, c_fake_loss: 0.0001
# Epoch [31/100], Step [801/938], d_loss: 0.4294, g_loss: 2.5203, q_loss: 0.0312, c_real_loss: 0.0012, c_fake_loss: 0.0002
# Epoch [31/100], Step [901/938], d_loss: 0.6746, g_loss: 2.2889, q_loss: 0.0725, c_real_loss: 0.0056, c_fake_loss: 0.0009
# Epoch [32/100], Step [1/938], d_loss: 0.7410, g_loss: 3.6890, q_loss: 0.1531, c_real_loss: 0.0026, c_fake_loss: 0.0017
# Epoch [32/100], Step [101/938], d_loss: 0.7706, g_loss: 2.5160, q_loss: 0.0441, c_real_loss: 0.0011, c_fake_loss: 0.0001
# Epoch [32/100], Step [201/938], d_loss: 0.3910, g_loss: 2.5334, q_loss: 0.0260, c_real_loss: 0.0009, c_fake_loss: 0.0024
# Epoch [32/100], Step [301/938], d_loss: 0.4676, g_loss: 2.3807, q_loss: 0.2144, c_real_loss: 0.0008, c_fake_loss: 0.0002
# Epoch [32/100], Step [401/938], d_loss: 0.4761, g_loss: 2.2248, q_loss: 0.1312, c_real_loss: 0.0007, c_fake_loss: 0.0004
# Epoch [32/100], Step [501/938], d_loss: 0.6245, g_loss: 2.7945, q_loss: 0.0472, c_real_loss: 0.0013, c_fake_loss: 0.0009
# Epoch [32/100], Step [601/938], d_loss: 0.5699, g_loss: 2.2285, q_loss: 0.0882, c_real_loss: 0.0004, c_fake_loss: 0.0007
# Epoch [32/100], Step [701/938], d_loss: 0.4982, g_loss: 3.0135, q_loss: 0.0285, c_real_loss: 0.0004, c_fake_loss: 0.0020
# Epoch [32/100], Step [801/938], d_loss: 0.7990, g_loss: 2.1056, q_loss: 0.1307, c_real_loss: 0.0028, c_fake_loss: 0.0071
# Epoch [32/100], Step [901/938], d_loss: 0.5716, g_loss: 2.4328, q_loss: 0.0317, c_real_loss: 0.0031, c_fake_loss: 0.0153
# Epoch [33/100], Step [1/938], d_loss: 0.5066, g_loss: 2.3619, q_loss: 0.0984, c_real_loss: 0.0089, c_fake_loss: 0.0001
# Epoch [33/100], Step [101/938], d_loss: 0.4570, g_loss: 2.5688, q_loss: 0.0771, c_real_loss: 0.0014, c_fake_loss: 0.0006
# Epoch [33/100], Step [201/938], d_loss: 0.6702, g_loss: 2.2202, q_loss: 0.0307, c_real_loss: 0.0004, c_fake_loss: 0.0003
# Epoch [33/100], Step [301/938], d_loss: 0.8029, g_loss: 2.1592, q_loss: 0.0749, c_real_loss: 0.0051, c_fake_loss: 0.0023
# Epoch [33/100], Step [401/938], d_loss: 0.4723, g_loss: 3.4069, q_loss: 0.1456, c_real_loss: 0.0002, c_fake_loss: 0.0021
# Epoch [33/100], Step [501/938], d_loss: 0.3970, g_loss: 2.2575, q_loss: 0.0376, c_real_loss: 0.0044, c_fake_loss: 0.0044
# Epoch [33/100], Step [601/938], d_loss: 0.8856, g_loss: 2.9751, q_loss: 0.0859, c_real_loss: 0.0005, c_fake_loss: 0.0059
# Epoch [33/100], Step [701/938], d_loss: 0.5267, g_loss: 3.0794, q_loss: 0.0463, c_real_loss: 0.0052, c_fake_loss: 0.0001
# Epoch [33/100], Step [801/938], d_loss: 0.5288, g_loss: 2.6377, q_loss: 0.0243, c_real_loss: 0.0210, c_fake_loss: 0.0004
# Epoch [33/100], Step [901/938], d_loss: 0.4886, g_loss: 2.6161, q_loss: 0.0737, c_real_loss: 0.0004, c_fake_loss: 0.0003
# Epoch [34/100], Step [1/938], d_loss: 0.7459, g_loss: 2.7750, q_loss: 0.0494, c_real_loss: 0.0012, c_fake_loss: 0.0003
# Epoch [34/100], Step [101/938], d_loss: 0.3986, g_loss: 2.4440, q_loss: 0.0861, c_real_loss: 0.0049, c_fake_loss: 0.0022
# Epoch [34/100], Step [201/938], d_loss: 0.5580, g_loss: 2.5646, q_loss: 0.0221, c_real_loss: 0.0007, c_fake_loss: 0.0002
# Epoch [34/100], Step [301/938], d_loss: 0.6732, g_loss: 3.1258, q_loss: 0.0528, c_real_loss: 0.0000, c_fake_loss: 0.0024
# Epoch [34/100], Step [401/938], d_loss: 0.4774, g_loss: 1.9735, q_loss: 0.0298, c_real_loss: 0.0002, c_fake_loss: 0.0010
# Epoch [34/100], Step [501/938], d_loss: 0.3653, g_loss: 2.4729, q_loss: 0.1511, c_real_loss: 0.0009, c_fake_loss: 0.0002
# Epoch [34/100], Step [601/938], d_loss: 0.5233, g_loss: 3.1720, q_loss: 0.0477, c_real_loss: 0.0033, c_fake_loss: 0.0031
# Epoch [34/100], Step [701/938], d_loss: 0.4212, g_loss: 2.8072, q_loss: 0.0283, c_real_loss: 0.0114, c_fake_loss: 0.0002
# Epoch [34/100], Step [801/938], d_loss: 0.9222, g_loss: 1.6601, q_loss: 0.0256, c_real_loss: 0.0009, c_fake_loss: 0.0001
# Epoch [34/100], Step [901/938], d_loss: 0.6796, g_loss: 3.1007, q_loss: 0.0451, c_real_loss: 0.0211, c_fake_loss: 0.0003
# Epoch [35/100], Step [1/938], d_loss: 0.5678, g_loss: 2.8721, q_loss: 0.0486, c_real_loss: 0.0021, c_fake_loss: 0.0004
# Epoch [35/100], Step [101/938], d_loss: 0.6592, g_loss: 1.9163, q_loss: 0.0928, c_real_loss: 0.0057, c_fake_loss: 0.0007
# Epoch [35/100], Step [201/938], d_loss: 0.7620, g_loss: 1.7606, q_loss: 0.1007, c_real_loss: 0.0001, c_fake_loss: 0.0017
# Epoch [35/100], Step [301/938], d_loss: 0.6066, g_loss: 2.1269, q_loss: 0.0742, c_real_loss: 0.0049, c_fake_loss: 0.0006
# Epoch [35/100], Step [401/938], d_loss: 0.6750, g_loss: 2.5720, q_loss: 0.0589, c_real_loss: 0.0001, c_fake_loss: 0.0019
# Epoch [35/100], Step [501/938], d_loss: 0.4613, g_loss: 2.6491, q_loss: 0.0885, c_real_loss: 0.0011, c_fake_loss: 0.0001
# Epoch [35/100], Step [601/938], d_loss: 0.5403, g_loss: 1.6134, q_loss: 0.0340, c_real_loss: 0.0006, c_fake_loss: 0.0002
# Epoch [35/100], Step [701/938], d_loss: 0.4205, g_loss: 2.6887, q_loss: 0.0273, c_real_loss: 0.0099, c_fake_loss: 0.0005
# Epoch [35/100], Step [801/938], d_loss: 0.5048, g_loss: 1.9759, q_loss: 0.0412, c_real_loss: 0.0376, c_fake_loss: 0.0001
# Epoch [35/100], Step [901/938], d_loss: 0.4656, g_loss: 1.6031, q_loss: 0.0496, c_real_loss: 0.0028, c_fake_loss: 0.0000
# Epoch [36/100], Step [1/938], d_loss: 0.6031, g_loss: 2.7724, q_loss: 0.1858, c_real_loss: 0.0015, c_fake_loss: 0.0008
# Epoch [36/100], Step [101/938], d_loss: 0.4660, g_loss: 2.7365, q_loss: 0.0814, c_real_loss: 0.0027, c_fake_loss: 0.0022
# Epoch [36/100], Step [201/938], d_loss: 0.8153, g_loss: 2.5044, q_loss: 0.0361, c_real_loss: 0.0105, c_fake_loss: 0.0002
# Epoch [36/100], Step [301/938], d_loss: 0.6683, g_loss: 2.9772, q_loss: 0.1027, c_real_loss: 0.0011, c_fake_loss: 0.0004
# Epoch [36/100], Step [401/938], d_loss: 0.8891, g_loss: 2.9277, q_loss: 0.0188, c_real_loss: 0.0007, c_fake_loss: 0.0001
# Epoch [36/100], Step [501/938], d_loss: 0.5538, g_loss: 2.8211, q_loss: 0.0271, c_real_loss: 0.0005, c_fake_loss: 0.0004
# Epoch [36/100], Step [601/938], d_loss: 0.3654, g_loss: 2.2609, q_loss: 0.0446, c_real_loss: 0.0007, c_fake_loss: 0.0016
# Epoch [36/100], Step [701/938], d_loss: 0.6746, g_loss: 3.2448, q_loss: 0.0639, c_real_loss: 0.0097, c_fake_loss: 0.0009
# Epoch [36/100], Step [801/938], d_loss: 0.6809, g_loss: 2.7926, q_loss: 0.0330, c_real_loss: 0.0016, c_fake_loss: 0.0579
# Epoch [36/100], Step [901/938], d_loss: 0.6001, g_loss: 3.6217, q_loss: 0.0576, c_real_loss: 0.0064, c_fake_loss: 0.0002
# Epoch [37/100], Step [1/938], d_loss: 0.6153, g_loss: 2.4324, q_loss: 0.0887, c_real_loss: 0.0005, c_fake_loss: 0.0004
# Epoch [37/100], Step [101/938], d_loss: 0.5442, g_loss: 2.7610, q_loss: 0.0464, c_real_loss: 0.0044, c_fake_loss: 0.0002
# Epoch [37/100], Step [201/938], d_loss: 0.8606, g_loss: 2.2797, q_loss: 0.0367, c_real_loss: 0.0353, c_fake_loss: 0.0006
# Epoch [37/100], Step [301/938], d_loss: 0.5836, g_loss: 2.3664, q_loss: 0.1136, c_real_loss: 0.0008, c_fake_loss: 0.0003
# Epoch [37/100], Step [401/938], d_loss: 0.6556, g_loss: 3.9401, q_loss: 0.3187, c_real_loss: 0.0051, c_fake_loss: 0.0001
# Epoch [37/100], Step [501/938], d_loss: 0.5399, g_loss: 2.6834, q_loss: 0.1256, c_real_loss: 0.0016, c_fake_loss: 0.0001
# Epoch [37/100], Step [601/938], d_loss: 0.3960, g_loss: 2.9274, q_loss: 0.0671, c_real_loss: 0.0023, c_fake_loss: 0.0001
# Epoch [37/100], Step [701/938], d_loss: 0.4396, g_loss: 2.8912, q_loss: 0.1325, c_real_loss: 0.0117, c_fake_loss: 0.0106
# Epoch [37/100], Step [801/938], d_loss: 0.4558, g_loss: 2.8372, q_loss: 0.0335, c_real_loss: 0.0029, c_fake_loss: 0.0002
# Epoch [37/100], Step [901/938], d_loss: 0.5447, g_loss: 2.2804, q_loss: 0.0424, c_real_loss: 0.0000, c_fake_loss: 0.0004
# Epoch [38/100], Step [1/938], d_loss: 0.5887, g_loss: 2.9633, q_loss: 0.0675, c_real_loss: 0.0037, c_fake_loss: 0.0195
# Epoch [38/100], Step [101/938], d_loss: 0.5933, g_loss: 2.6583, q_loss: 0.0268, c_real_loss: 0.0000, c_fake_loss: 0.0001
# Epoch [38/100], Step [201/938], d_loss: 0.4903, g_loss: 2.7932, q_loss: 0.0995, c_real_loss: 0.0055, c_fake_loss: 0.0036
# Epoch [38/100], Step [301/938], d_loss: 0.6124, g_loss: 2.8975, q_loss: 0.0777, c_real_loss: 0.0009, c_fake_loss: 0.0007
# Epoch [38/100], Step [401/938], d_loss: 0.3545, g_loss: 2.8366, q_loss: 0.0678, c_real_loss: 0.0078, c_fake_loss: 0.0007
# Epoch [38/100], Step [501/938], d_loss: 0.5342, g_loss: 2.9988, q_loss: 0.0343, c_real_loss: 0.0039, c_fake_loss: 0.0001
# Epoch [38/100], Step [601/938], d_loss: 0.5493, g_loss: 2.3574, q_loss: 0.0554, c_real_loss: 0.0007, c_fake_loss: 0.0018
# Epoch [38/100], Step [701/938], d_loss: 0.5855, g_loss: 3.2507, q_loss: 0.0284, c_real_loss: 0.0002, c_fake_loss: 0.0005
# Epoch [38/100], Step [801/938], d_loss: 0.4137, g_loss: 2.4104, q_loss: 0.0349, c_real_loss: 0.0023, c_fake_loss: 0.0001
# Epoch [38/100], Step [901/938], d_loss: 0.4186, g_loss: 3.6088, q_loss: 0.0759, c_real_loss: 0.0004, c_fake_loss: 0.0001
# Epoch [39/100], Step [1/938], d_loss: 0.4680, g_loss: 2.8897, q_loss: 0.1006, c_real_loss: 0.0007, c_fake_loss: 0.0001
# Epoch [39/100], Step [101/938], d_loss: 0.7278, g_loss: 1.9874, q_loss: 0.0919, c_real_loss: 0.0056, c_fake_loss: 0.0000
# Epoch [39/100], Step [201/938], d_loss: 0.4344, g_loss: 2.6606, q_loss: 0.0976, c_real_loss: 0.0079, c_fake_loss: 0.0012
# Epoch [39/100], Step [301/938], d_loss: 0.5065, g_loss: 2.2547, q_loss: 0.0647, c_real_loss: 0.0008, c_fake_loss: 0.0000
# Epoch [39/100], Step [401/938], d_loss: 0.4788, g_loss: 2.8185, q_loss: 0.0997, c_real_loss: 0.0003, c_fake_loss: 0.0002
# Epoch [39/100], Step [501/938], d_loss: 0.6969, g_loss: 2.1465, q_loss: 0.0256, c_real_loss: 0.0075, c_fake_loss: 0.0002
# Epoch [39/100], Step [601/938], d_loss: 0.5563, g_loss: 2.2469, q_loss: 0.0540, c_real_loss: 0.0105, c_fake_loss: 0.0053
# Epoch [39/100], Step [701/938], d_loss: 0.2984, g_loss: 3.4385, q_loss: 0.0562, c_real_loss: 0.0060, c_fake_loss: 0.0003
# Epoch [39/100], Step [801/938], d_loss: 0.3744, g_loss: 2.0588, q_loss: 0.0752, c_real_loss: 0.0084, c_fake_loss: 0.0008
# Epoch [39/100], Step [901/938], d_loss: 0.4897, g_loss: 2.9469, q_loss: 0.0846, c_real_loss: 0.0049, c_fake_loss: 0.0002
# Epoch [40/100], Step [1/938], d_loss: 0.5689, g_loss: 4.2568, q_loss: 0.1577, c_real_loss: 0.0051, c_fake_loss: 0.0002
# Epoch [40/100], Step [101/938], d_loss: 0.3077, g_loss: 2.6892, q_loss: 0.0901, c_real_loss: 0.0026, c_fake_loss: 0.0003
# Epoch [40/100], Step [201/938], d_loss: 0.4937, g_loss: 1.9214, q_loss: 0.0414, c_real_loss: 0.0182, c_fake_loss: 0.0007
# Epoch [40/100], Step [301/938], d_loss: 0.5751, g_loss: 3.5672, q_loss: 0.0337, c_real_loss: 0.0213, c_fake_loss: 0.0005
# Epoch [40/100], Step [401/938], d_loss: 0.6099, g_loss: 2.8927, q_loss: 0.0655, c_real_loss: 0.0030, c_fake_loss: 0.0001
# Epoch [40/100], Step [501/938], d_loss: 0.6534, g_loss: 3.2364, q_loss: 0.1466, c_real_loss: 0.0004, c_fake_loss: 0.0000
# Epoch [40/100], Step [601/938], d_loss: 0.4714, g_loss: 3.3460, q_loss: 0.0544, c_real_loss: 0.0008, c_fake_loss: 0.0006
# Epoch [40/100], Step [701/938], d_loss: 0.4485, g_loss: 3.3244, q_loss: 0.0769, c_real_loss: 0.0013, c_fake_loss: 0.0005
# Epoch [40/100], Step [801/938], d_loss: 0.4780, g_loss: 1.9027, q_loss: 0.0637, c_real_loss: 0.0013, c_fake_loss: 0.0002
# Epoch [40/100], Step [901/938], d_loss: 0.6246, g_loss: 2.6182, q_loss: 0.0302, c_real_loss: 0.0006, c_fake_loss: 0.0003
# Epoch [41/100], Step [1/938], d_loss: 0.7751, g_loss: 2.5498, q_loss: 0.0332, c_real_loss: 0.0006, c_fake_loss: 0.0005
# Epoch [41/100], Step [101/938], d_loss: 0.5203, g_loss: 2.6374, q_loss: 0.0560, c_real_loss: 0.0012, c_fake_loss: 0.0001
# Epoch [41/100], Step [201/938], d_loss: 0.6445, g_loss: 2.1575, q_loss: 0.0407, c_real_loss: 0.0020, c_fake_loss: 0.0008
# Epoch [41/100], Step [301/938], d_loss: 0.4728, g_loss: 2.7240, q_loss: 0.0597, c_real_loss: 0.0014, c_fake_loss: 0.0026
# Epoch [41/100], Step [401/938], d_loss: 0.4852, g_loss: 3.1074, q_loss: 0.0631, c_real_loss: 0.0017, c_fake_loss: 0.0008
# Epoch [41/100], Step [501/938], d_loss: 0.5242, g_loss: 3.0320, q_loss: 0.1255, c_real_loss: 0.0005, c_fake_loss: 0.0001
# Epoch [41/100], Step [601/938], d_loss: 1.1606, g_loss: 3.2952, q_loss: 0.0623, c_real_loss: 0.0040, c_fake_loss: 0.0000
# Epoch [41/100], Step [701/938], d_loss: 0.4259, g_loss: 2.6976, q_loss: 0.0705, c_real_loss: 0.0001, c_fake_loss: 0.0000
# Epoch [41/100], Step [801/938], d_loss: 0.8454, g_loss: 3.1322, q_loss: 0.0601, c_real_loss: 0.0019, c_fake_loss: 0.0001
# Epoch [41/100], Step [901/938], d_loss: 0.3715, g_loss: 3.5093, q_loss: 0.0404, c_real_loss: 0.0001, c_fake_loss: 0.0002
# Epoch [42/100], Step [1/938], d_loss: 0.4954, g_loss: 3.8212, q_loss: 0.0311, c_real_loss: 0.0039, c_fake_loss: 0.0003
# Epoch [42/100], Step [101/938], d_loss: 0.5661, g_loss: 3.2131, q_loss: 0.0240, c_real_loss: 0.0009, c_fake_loss: 0.0001
# Epoch [42/100], Step [201/938], d_loss: 0.5012, g_loss: 2.2783, q_loss: 0.2235, c_real_loss: 0.0011, c_fake_loss: 0.0000
# Epoch [42/100], Step [301/938], d_loss: 0.5740, g_loss: 1.8037, q_loss: 0.0453, c_real_loss: 0.0009, c_fake_loss: 0.0012
# Epoch [42/100], Step [401/938], d_loss: 0.5607, g_loss: 2.2991, q_loss: 0.0741, c_real_loss: 0.0023, c_fake_loss: 0.0001
# Epoch [42/100], Step [501/938], d_loss: 0.6017, g_loss: 3.5281, q_loss: 0.0822, c_real_loss: 0.0001, c_fake_loss: 0.0000
# Epoch [42/100], Step [601/938], d_loss: 0.3990, g_loss: 2.2513, q_loss: 0.0810, c_real_loss: 0.0003, c_fake_loss: 0.0001
# Epoch [42/100], Step [701/938], d_loss: 0.4397, g_loss: 4.1457, q_loss: 0.0799, c_real_loss: 0.0224, c_fake_loss: 0.0002
# Epoch [42/100], Step [801/938], d_loss: 0.6181, g_loss: 3.5793, q_loss: 0.1703, c_real_loss: 0.0004, c_fake_loss: 0.0002
# Epoch [42/100], Step [901/938], d_loss: 0.2913, g_loss: 3.0650, q_loss: 0.0289, c_real_loss: 0.0016, c_fake_loss: 0.0007
# Epoch [43/100], Step [1/938], d_loss: 0.7771, g_loss: 4.1216, q_loss: 0.0283, c_real_loss: 0.0002, c_fake_loss: 0.0000
# Epoch [43/100], Step [101/938], d_loss: 0.2984, g_loss: 3.2407, q_loss: 0.0275, c_real_loss: 0.0002, c_fake_loss: 0.0008
# Epoch [43/100], Step [201/938], d_loss: 0.3228, g_loss: 2.8909, q_loss: 0.0238, c_real_loss: 0.0005, c_fake_loss: 0.0001
# Epoch [43/100], Step [301/938], d_loss: 0.5930, g_loss: 3.5038, q_loss: 0.0379, c_real_loss: 0.0030, c_fake_loss: 0.0002
# Epoch [43/100], Step [401/938], d_loss: 0.5580, g_loss: 3.1194, q_loss: 0.0235, c_real_loss: 0.0001, c_fake_loss: 0.0000
# Epoch [43/100], Step [501/938], d_loss: 0.5123, g_loss: 4.2709, q_loss: 0.0598, c_real_loss: 0.0015, c_fake_loss: 0.0001
# Epoch [43/100], Step [601/938], d_loss: 0.3153, g_loss: 2.6440, q_loss: 0.0487, c_real_loss: 0.0032, c_fake_loss: 0.0001
# Epoch [43/100], Step [701/938], d_loss: 0.5834, g_loss: 2.7367, q_loss: 0.0237, c_real_loss: 0.0001, c_fake_loss: 0.0001
# Epoch [43/100], Step [801/938], d_loss: 0.3584, g_loss: 3.1941, q_loss: 0.2021, c_real_loss: 0.0006, c_fake_loss: 0.0008
# Epoch [43/100], Step [901/938], d_loss: 0.4626, g_loss: 3.2569, q_loss: 0.0762, c_real_loss: 0.0002, c_fake_loss: 0.0001
# Epoch [44/100], Step [1/938], d_loss: 0.6329, g_loss: 3.5718, q_loss: 0.0799, c_real_loss: 0.0090, c_fake_loss: 0.0067
# Epoch [44/100], Step [101/938], d_loss: 0.5572, g_loss: 3.3490, q_loss: 0.0689, c_real_loss: 0.0007, c_fake_loss: 0.0001
# Epoch [44/100], Step [201/938], d_loss: 0.5290, g_loss: 2.9625, q_loss: 0.0437, c_real_loss: 0.0008, c_fake_loss: 0.0005
# Epoch [44/100], Step [301/938], d_loss: 0.5576, g_loss: 3.3272, q_loss: 0.1633, c_real_loss: 0.0002, c_fake_loss: 0.0004
# Epoch [44/100], Step [401/938], d_loss: 0.4446, g_loss: 3.1156, q_loss: 0.0693, c_real_loss: 0.0002, c_fake_loss: 0.0000
# Epoch [44/100], Step [501/938], d_loss: 0.4153, g_loss: 2.8401, q_loss: 0.0583, c_real_loss: 0.0040, c_fake_loss: 0.0126
# Epoch [44/100], Step [601/938], d_loss: 0.3574, g_loss: 2.6849, q_loss: 0.0514, c_real_loss: 0.0011, c_fake_loss: 0.0001
# Epoch [44/100], Step [701/938], d_loss: 0.5469, g_loss: 3.2378, q_loss: 0.0613, c_real_loss: 0.0031, c_fake_loss: 0.0005
# Epoch [44/100], Step [801/938], d_loss: 0.3906, g_loss: 2.5127, q_loss: 0.0337, c_real_loss: 0.0008, c_fake_loss: 0.0000
# Epoch [44/100], Step [901/938], d_loss: 0.3985, g_loss: 3.0094, q_loss: 0.0313, c_real_loss: 0.0009, c_fake_loss: 0.0002
# Epoch [45/100], Step [1/938], d_loss: 0.5304, g_loss: 3.8678, q_loss: 0.0536, c_real_loss: 0.0060, c_fake_loss: 0.0135
# Epoch [45/100], Step [101/938], d_loss: 0.4005, g_loss: 2.8142, q_loss: 0.0723, c_real_loss: 0.0008, c_fake_loss: 0.0001
# Epoch [45/100], Step [201/938], d_loss: 0.5241, g_loss: 3.1659, q_loss: 0.0318, c_real_loss: 0.0007, c_fake_loss: 0.0086
# Epoch [45/100], Step [301/938], d_loss: 0.3013, g_loss: 2.7971, q_loss: 0.0161, c_real_loss: 0.0024, c_fake_loss: 0.0001
# Epoch [45/100], Step [401/938], d_loss: 0.5380, g_loss: 2.7147, q_loss: 0.0785, c_real_loss: 0.0013, c_fake_loss: 0.0027
# Epoch [45/100], Step [501/938], d_loss: 0.5192, g_loss: 2.7852, q_loss: 0.0650, c_real_loss: 0.0019, c_fake_loss: 0.0007
# Epoch [45/100], Step [601/938], d_loss: 0.5290, g_loss: 2.5209, q_loss: 0.0273, c_real_loss: 0.0011, c_fake_loss: 0.0046
# Epoch [45/100], Step [701/938], d_loss: 0.6548, g_loss: 3.0194, q_loss: 0.0373, c_real_loss: 0.0104, c_fake_loss: 0.0001
# Epoch [45/100], Step [801/938], d_loss: 0.3914, g_loss: 2.3386, q_loss: 0.0501, c_real_loss: 0.0023, c_fake_loss: 0.0004
# Epoch [45/100], Step [901/938], d_loss: 0.3371, g_loss: 2.8074, q_loss: 0.0229, c_real_loss: 0.0094, c_fake_loss: 0.0050
# Epoch [46/100], Step [1/938], d_loss: 0.5083, g_loss: 2.6290, q_loss: 0.0868, c_real_loss: 0.0016, c_fake_loss: 0.0001
# Epoch [46/100], Step [101/938], d_loss: 0.5457, g_loss: 2.2613, q_loss: 0.0354, c_real_loss: 0.0028, c_fake_loss: 0.0001
# Epoch [46/100], Step [201/938], d_loss: 0.6278, g_loss: 3.0891, q_loss: 0.0260, c_real_loss: 0.0565, c_fake_loss: 0.0000
# Epoch [46/100], Step [301/938], d_loss: 0.5254, g_loss: 2.4700, q_loss: 0.0546, c_real_loss: 0.0002, c_fake_loss: 0.0003
# Epoch [46/100], Step [401/938], d_loss: 0.4036, g_loss: 3.8808, q_loss: 0.0397, c_real_loss: 0.0047, c_fake_loss: 0.0125
# Epoch [46/100], Step [501/938], d_loss: 0.3619, g_loss: 3.4799, q_loss: 0.1023, c_real_loss: 0.0030, c_fake_loss: 0.0003
# Epoch [46/100], Step [601/938], d_loss: 0.4825, g_loss: 2.8183, q_loss: 0.0401, c_real_loss: 0.0006, c_fake_loss: 0.0175
# Epoch [46/100], Step [701/938], d_loss: 0.4432, g_loss: 2.2649, q_loss: 0.0786, c_real_loss: 0.0004, c_fake_loss: 0.0264
# Epoch [46/100], Step [801/938], d_loss: 0.5376, g_loss: 2.7428, q_loss: 0.0267, c_real_loss: 0.0718, c_fake_loss: 0.0003
# Epoch [46/100], Step [901/938], d_loss: 0.6336, g_loss: 3.4992, q_loss: 0.0363, c_real_loss: 0.0002, c_fake_loss: 0.0002
# Epoch [47/100], Step [1/938], d_loss: 0.7345, g_loss: 4.0353, q_loss: 0.0350, c_real_loss: 0.0041, c_fake_loss: 0.0332
# Epoch [47/100], Step [101/938], d_loss: 0.3382, g_loss: 3.7518, q_loss: 0.0857, c_real_loss: 0.0008, c_fake_loss: 0.0001
# Epoch [47/100], Step [201/938], d_loss: 0.5185, g_loss: 2.6021, q_loss: 0.0684, c_real_loss: 0.0038, c_fake_loss: 0.0001
# Epoch [47/100], Step [301/938], d_loss: 0.4770, g_loss: 3.6090, q_loss: 0.0389, c_real_loss: 0.0007, c_fake_loss: 0.0019
# Epoch [47/100], Step [401/938], d_loss: 0.4729, g_loss: 2.0505, q_loss: 0.0605, c_real_loss: 0.0042, c_fake_loss: 0.0011
# Epoch [47/100], Step [501/938], d_loss: 0.3986, g_loss: 2.9080, q_loss: 0.0759, c_real_loss: 0.0011, c_fake_loss: 0.0006
# Epoch [47/100], Step [601/938], d_loss: 0.3788, g_loss: 2.9512, q_loss: 0.0254, c_real_loss: 0.0315, c_fake_loss: 0.0177
# Epoch [47/100], Step [701/938], d_loss: 0.3972, g_loss: 2.5371, q_loss: 0.0317, c_real_loss: 0.0043, c_fake_loss: 0.0011
# Epoch [47/100], Step [801/938], d_loss: 0.4750, g_loss: 2.6912, q_loss: 0.0565, c_real_loss: 0.0012, c_fake_loss: 0.0002
# Epoch [47/100], Step [901/938], d_loss: 0.7653, g_loss: 3.8094, q_loss: 0.0249, c_real_loss: 0.0019, c_fake_loss: 0.0133
# Epoch [48/100], Step [1/938], d_loss: 0.7678, g_loss: 4.4021, q_loss: 0.0858, c_real_loss: 0.0014, c_fake_loss: 0.0129
# Epoch [48/100], Step [101/938], d_loss: 0.3671, g_loss: 3.1855, q_loss: 0.0413, c_real_loss: 0.0022, c_fake_loss: 0.0002
# Epoch [48/100], Step [201/938], d_loss: 0.7785, g_loss: 1.6558, q_loss: 0.0683, c_real_loss: 0.0005, c_fake_loss: 0.0025
# Epoch [48/100], Step [301/938], d_loss: 0.5584, g_loss: 2.2734, q_loss: 0.0679, c_real_loss: 0.0006, c_fake_loss: 0.0003
# Epoch [48/100], Step [401/938], d_loss: 0.4510, g_loss: 3.0390, q_loss: 0.0335, c_real_loss: 0.0038, c_fake_loss: 0.0000
# Epoch [48/100], Step [501/938], d_loss: 0.4976, g_loss: 3.8191, q_loss: 0.0232, c_real_loss: 0.0022, c_fake_loss: 0.0001
# Epoch [48/100], Step [601/938], d_loss: 0.4493, g_loss: 2.4369, q_loss: 0.0349, c_real_loss: 0.0118, c_fake_loss: 0.0003
# Epoch [48/100], Step [701/938], d_loss: 0.3951, g_loss: 3.2143, q_loss: 0.0657, c_real_loss: 0.0005, c_fake_loss: 0.0001
# Epoch [48/100], Step [801/938], d_loss: 0.4895, g_loss: 2.6620, q_loss: 0.0355, c_real_loss: 0.0014, c_fake_loss: 0.0016
# Epoch [48/100], Step [901/938], d_loss: 0.3009, g_loss: 2.8950, q_loss: 0.0554, c_real_loss: 0.0002, c_fake_loss: 0.0038
# Epoch [49/100], Step [1/938], d_loss: 0.3724, g_loss: 2.9412, q_loss: 0.0593, c_real_loss: 0.0006, c_fake_loss: 0.0036
# Epoch [49/100], Step [101/938], d_loss: 0.4582, g_loss: 2.7648, q_loss: 0.0440, c_real_loss: 0.0001, c_fake_loss: 0.0002
# Epoch [49/100], Step [201/938], d_loss: 0.7700, g_loss: 2.4306, q_loss: 0.0245, c_real_loss: 0.0082, c_fake_loss: 0.0215
# Epoch [49/100], Step [301/938], d_loss: 0.2234, g_loss: 2.6053, q_loss: 0.0358, c_real_loss: 0.0006, c_fake_loss: 0.0006
# Epoch [49/100], Step [401/938], d_loss: 0.4196, g_loss: 2.6555, q_loss: 0.0878, c_real_loss: 0.0019, c_fake_loss: 0.0000
# Epoch [49/100], Step [501/938], d_loss: 0.4387, g_loss: 1.9082, q_loss: 0.0209, c_real_loss: 0.0032, c_fake_loss: 0.0002
# Epoch [49/100], Step [601/938], d_loss: 0.3604, g_loss: 3.4309, q_loss: 0.0263, c_real_loss: 0.0013, c_fake_loss: 0.0000
